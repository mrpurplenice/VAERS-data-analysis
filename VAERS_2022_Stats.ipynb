# %% [markdown]
# ## Importing the libraries

# %% [markdown]
# Using set_option(), we can change the default number of rows to be displayed.
# the maximum number of rows and columns to display to unlimited, allowing the  full DataFrame to be displayed when printed.

# %%
import pandas as pd
import re
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Importing the dataset

# %% [markdown]
# By default, Pandas has the low_memory=True argument. This means that the CSV file gets split up in multiple chunks and the guess is done for every chunk, resulting in a column with multiple dtypes. By setting the low_memory argument to False, you’re basically telling Pandas not to be efficient, and process the whole file, all at once.

# %% [markdown]
# Latin-1 is the same as 8859-1. Every character is encoded as a single byte. There are 191 characters total.

# %%
vdata = pd.read_csv('2022VAERSDATA.csv', encoding='latin1',low_memory=False)
vvax = pd.read_csv('2022VAERSVAX.csv',encoding='latin1',low_memory=False)
vsymp = pd.read_csv('2022VAERSSYMPTOMS.csv',encoding='latin1',low_memory=False)

# %% [markdown]
# # Checking data frames

# %% [markdown]
# Pandas head() method is used to return top n (5 by default) rows of a data frame or series.

# %%
vdata.head()
# Out:
#    VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0   1996873  01/01/2022    CA      NaN      NaN      NaN   U      NaN
# 1   1996874  01/01/2022   NaN      NaN      NaN      NaN   U      NaN
# 2   1996875  01/01/2022    OH      NaN      NaN      NaN   M      NaN
# 3   1996876  01/01/2022    MS     34.0      NaN      NaN   F      NaN
# 4   1996877  01/01/2022    CT      NaN      NaN      NaN   F      NaN
#
#                                         SYMPTOM_TEXT DIED DATEDIED L_THREAT  \
# 0  This spontaneous report was received from a ph...  NaN      NaN      NaN
# 1  SUSPECTED CLINICAL VACCINATION FAILURE; SUSPEC...  NaN      NaN      NaN
# 2  SUSPECTED CLINICAL VACCINATION FAILURE; SUSPEC...  NaN      NaN      NaN
# 3  Irregular menstrual cycle.; period extremely h...  NaN      NaN      NaN
# 4  Breakthrough and heavy periods; longer period ...  NaN      NaN      NaN
#
#   ER_VISIT HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD    VAX_DATE  ONSET_DATE  \
# 0      NaN      NaN       NaN    NaN     NaN      U  12/15/2021  12/15/2021
# 1      NaN      NaN       NaN    NaN     NaN      U         NaN         NaN
# 2      NaN      NaN       NaN    NaN     NaN      U         NaN  12/28/2021
# 3      NaN      NaN       NaN    NaN     NaN      N  08/18/2021  09/03/2021
# 4      NaN      NaN       NaN    NaN     NaN      N  03/26/2021  06/07/2021
#
#    NUMDAYS                                           LAB_DATA V_ADMINBY  \
# 0      0.0                                                NaN       UNK
# 1      NaN                                                NaN       UNK
# 2      NaN  Test Date: 20211230; Test Name: COVID-19 antig...       OTH
# 3     16.0                                                NaN       PVT
# 4     73.0  Test Date: 20210921; Test Name: Nasal Swab; Re...       PVT
#
#   V_FUNDBY                   OTHER_MEDS CUR_ILL  \
# 0      NaN                          NaN     NaN
# 1      NaN                          NaN     NaN
# 2      NaN                          NaN     NaN
# 3      NaN  ZOLOFT; ORTHO-TRI-CYCLEN LO     NaN
# 4      NaN   ALDACTONE [SPIRONOLACTONE]     NaN
#
#                                              HISTORY PRIOR_VAX  \
# 0                                                NaN       NaN
# 1                                                NaN       NaN
# 2                                                NaN       NaN
# 3  Comments: List of non-encoded Patient Relevant...       NaN
# 4                                                NaN       NaN
#
#                    SPLTTYPE  FORM_VERS TODAYS_DATE BIRTH_DEFECT OFC_VISIT  \
# 0  US0095075132112USA007320          2  12/31/2021          NaN       NaN
# 1       USJNJFOC20211263430          2  01/01/2022          NaN       NaN
# 2       USJNJFOC20211266010          2  01/01/2022          NaN       NaN
# 3  USPFIZER INC202101162241          2  12/31/2021          NaN       NaN
# 4  USPFIZER INC202101281356          2  12/31/2021          NaN       NaN
#
#   ER_ED_VISIT ALLERGIES
# 0         NaN       NaN
# 1         NaN       NaN
# 2         NaN       NaN
# 3         NaN       NaN
# 4         NaN       NaN

# %%
vvax.head()
# Out:
#    VAERS_ID VAX_TYPE          VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_ROUTE  \
# 0   1996873     HPV9  MERCK & CO. INC.  R017624             UNK       NaN
# 1   1996874  COVID19           JANSSEN      NaN               1        OT
# 2   1996875  COVID19           JANSSEN  204A21A               1       NaN
# 3   1996876  COVID19   PFIZER\BIONTECH   Fd8448               2       NaN
# 4   1996877  COVID19   PFIZER\BIONTECH   EP6955               1       NaN
#
#   VAX_SITE                             VAX_NAME
# 0      NaN                     HPV (GARDASIL 9)
# 1      NaN          COVID19 (COVID19 (JANSSEN))
# 2      NaN          COVID19 (COVID19 (JANSSEN))
# 3       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 4       LA  COVID19 (COVID19 (PFIZER-BIONTECH))

# %%
vsymp.head()
# Out:
#    VAERS_ID                      SYMPTOM1  SYMPTOMVERSION1  \
# 0   1996873  Expired product administered             24.1
# 1   1996874            Suspected COVID-19             24.1
# 2   1996875               SARS-CoV-2 test             24.1
# 3   1996876                 Dysmenorrhoea             24.1
# 4   1996877      Heavy menstrual bleeding             24.1
#
#                    SYMPTOM2  SYMPTOMVERSION2                  SYMPTOM3  \
# 0          No adverse event             24.1                       NaN
# 1       Vaccination failure             24.1                       NaN
# 2        Suspected COVID-19             24.1       Vaccination failure
# 3  Heavy menstrual bleeding             24.1    Menstruation irregular
# 4           Oligomenorrhoea             24.1  SARS-CoV-2 test negative
#
#    SYMPTOMVERSION3 SYMPTOM4  SYMPTOMVERSION4 SYMPTOM5  SYMPTOMVERSION5
# 0              NaN      NaN              NaN      NaN              NaN
# 1              NaN      NaN              NaN      NaN              NaN
# 2             24.1      NaN              NaN      NaN              NaN
# 3             24.1      NaN              NaN      NaN              NaN
# 4             24.1      NaN              NaN      NaN              NaN

# %% [markdown]
# Pandas duplicated() method helps in analyzing duplicate values only. Counts duplicated VAERS ID.

# %%
tt = vsymp.duplicated(subset=['VAERS_ID'])
tt = tt.value_counts()
print(tt)
# Out:
# False    240841
# True      81137
# dtype: int64

# %% [markdown]
# The len() function returns the number of items in an object.

# %%
a = len(vdata)
b = len(vvax)
c = len(vsymp)
print(a,b,c)
# Out:
# 240841 276445 321978

# %% [markdown]
# The value_counts() function is used to get a Series containing counts of unique values.

# %%
vt= vdata.duplicated(subset=["VAERS_ID"])
vt= (vt.value_counts())
vv= vvax.duplicated(subset=["VAERS_ID"])
vv= (vv.value_counts())
vs= vsymp.duplicated(subset=["VAERS_ID"])
vs= (vs.value_counts())
print(vt,'\n',vv,'\n',vs)
# Out:
# False    240841
# dtype: int64
#  False    240841
# True      35604
# dtype: int64
#  False    240841
# True      81137
# dtype: int64

# %% [markdown]
# # Merging Data

# %% [markdown]
# Outer Merge returns all records from both the left or right dataframes. When rows in one dataframe do not match another dataframe, the merged dataframe will have NaN for the cells.  Use how=’outer’ in merge() to outer merge two dataframes in Pandas.

# %%
v1 = vdata.merge(vvax, on='VAERS_ID', how='outer')
v1
# Out:
#         VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0        1996873  01/01/2022    CA      NaN      NaN      NaN   U      NaN
# 1        1996874  01/01/2022   NaN      NaN      NaN      NaN   U      NaN
# 2        1996875  01/01/2022    OH      NaN      NaN      NaN   M      NaN
# 3        1996876  01/01/2022    MS     34.0      NaN      NaN   F      NaN
# 4        1996877  01/01/2022    CT      NaN      NaN      NaN   F      NaN
# ...          ...         ...   ...      ...      ...      ...  ..      ...
# 276440   2541569  12/23/2022   NaN      2.0      2.0      0.3   F      NaN
# 276441   2541570  12/23/2022   NaN     68.0      NaN      NaN   F      NaN
# 276442   2541571  12/23/2022   NaN     79.0      NaN      NaN   M      NaN
# 276443   2541572  12/23/2022   NaN     63.0      NaN      NaN   M      NaN
# 276444   2541574  12/23/2022    IN     12.0      NaN      NaN   F      NaN
#
#                                              SYMPTOM_TEXT DIED DATEDIED  \
# 0       This spontaneous report was received from a ph...  NaN      NaN
# 1       SUSPECTED CLINICAL VACCINATION FAILURE; SUSPEC...  NaN      NaN
# 2       SUSPECTED CLINICAL VACCINATION FAILURE; SUSPEC...  NaN      NaN
# 3       Irregular menstrual cycle.; period extremely h...  NaN      NaN
# 4       Breakthrough and heavy periods; longer period ...  NaN      NaN
# ...                                                   ...  ...      ...
# 276440  No adverse event; Vaccine administered after b...  NaN      NaN
# 276441  No adverse event; lot that had been expired wa...  NaN      NaN
# 276442  No adverse event; Expired vaccine used; This s...  NaN      NaN
# 276443  no adverse event; expired vaccine used; This s...  NaN      NaN
# 276444  patient's were administered the IPOL (opened) ...  NaN      NaN
#
#        L_THREAT ER_VISIT HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD    VAX_DATE  \
# 0           NaN      NaN      NaN       NaN    NaN     NaN      U  12/15/2021
# 1           NaN      NaN      NaN       NaN    NaN     NaN      U         NaN
# 2           NaN      NaN      NaN       NaN    NaN     NaN      U         NaN
# 3           NaN      NaN      NaN       NaN    NaN     NaN      N  08/18/2021
# 4           NaN      NaN      NaN       NaN    NaN     NaN      N  03/26/2021
# ...         ...      ...      ...       ...    ...     ...    ...         ...
# 276440      NaN      NaN      NaN       NaN    NaN     NaN      U  07/09/2022
# 276441      NaN      NaN      NaN       NaN    NaN     NaN      U         NaN
# 276442      NaN      NaN      NaN       NaN    NaN     NaN      U         NaN
# 276443      NaN      NaN      NaN       NaN    NaN     NaN      U         NaN
# 276444      NaN      NaN      NaN       NaN    NaN     NaN      U         NaN
#
#         ONSET_DATE  NUMDAYS  \
# 0       12/15/2021      0.0
# 1              NaN      NaN
# 2       12/28/2021      NaN
# 3       09/03/2021     16.0
# 4       06/07/2021     73.0
# ...            ...      ...
# 276440  07/09/2022      0.0
# 276441         NaN      NaN
# 276442         NaN      NaN
# 276443         NaN      NaN
# 276444         NaN      NaN
#
#                                                  LAB_DATA V_ADMINBY V_FUNDBY  \
# 0                                                     NaN       UNK      NaN
# 1                                                     NaN       UNK      NaN
# 2       Test Date: 20211230; Test Name: COVID-19 antig...       OTH      NaN
# 3                                                     NaN       PVT      NaN
# 4       Test Date: 20210921; Test Name: Nasal Swab; Re...       PVT      NaN
# ...                                                   ...       ...      ...
# 276440                                                NaN       UNK      NaN
# 276441                                                NaN       UNK      NaN
# 276442                                                NaN       UNK      NaN
# 276443                                                NaN       UNK      NaN
# 276444                                                NaN       UNK      NaN
#
#                          OTHER_MEDS CUR_ILL  \
# 0                               NaN     NaN
# 1                               NaN     NaN
# 2                               NaN     NaN
# 3       ZOLOFT; ORTHO-TRI-CYCLEN LO     NaN
# 4        ALDACTONE [SPIRONOLACTONE]     NaN
# ...                             ...     ...
# 276440                          NaN     NaN
# 276441                          NaN     NaN
# 276442                          NaN     NaN
# 276443                          NaN     NaN
# 276444                          NaN     NaN
#
#                                                   HISTORY PRIOR_VAX  \
# 0                                                     NaN       NaN
# 1                                                     NaN       NaN
# 2                                                     NaN       NaN
# 3       Comments: List of non-encoded Patient Relevant...       NaN
# 4                                                     NaN       NaN
# ...                                                   ...       ...
# 276440                                                NaN       NaN
# 276441                                                NaN       NaN
# 276442                                                NaN       NaN
# 276443                                                NaN       NaN
# 276444                                                NaN       NaN
#
#                          SPLTTYPE  FORM_VERS TODAYS_DATE BIRTH_DEFECT  \
# 0        US0095075132112USA007320          2  12/31/2021          NaN
# 1             USJNJFOC20211263430          2  01/01/2022          NaN
# 2             USJNJFOC20211266010          2  01/01/2022          NaN
# 3        USPFIZER INC202101162241          2  12/31/2021          NaN
# 4        USPFIZER INC202101281356          2  12/31/2021          NaN
# ...                           ...        ...         ...          ...
# 276440  USMODERNATX, INC.MOD20226          2  12/23/2022          NaN
# 276441  USMODERNATX, INC.MOD20226          2  12/23/2022          NaN
# 276442  USMODERNATX, INC.MOD20226          2  12/23/2022          NaN
# 276443  USMODERNATX, INC.MOD20226          2  12/23/2022          NaN
# 276444           USSA2022SA514948          2  12/23/2022          NaN
#
#        OFC_VISIT ER_ED_VISIT ALLERGIES VAX_TYPE          VAX_MANU  VAX_LOT  \
# 0            NaN         NaN       NaN     HPV9  MERCK & CO. INC.  R017624
# 1            NaN         NaN       NaN  COVID19           JANSSEN      NaN
# 2            NaN         NaN       NaN  COVID19           JANSSEN  204A21A
# 3            NaN         NaN       NaN  COVID19   PFIZER\BIONTECH   Fd8448
# 4            NaN         NaN       NaN  COVID19   PFIZER\BIONTECH   EP6955
# ...          ...         ...       ...      ...               ...      ...
# 276440       NaN         NaN       NaN  COVID19           MODERNA  AS1414B
# 276441       NaN         NaN       NaN  COVID19           MODERNA  O70H21A
# 276442       NaN         NaN       NaN  COVID19           MODERNA  O70H21A
# 276443       NaN         NaN       NaN  COVID19           MODERNA  O70H21A
# 276444       NaN         NaN       NaN      IPV    SANOFI PASTEUR      NaN
#
#        VAX_DOSE_SERIES VAX_ROUTE VAX_SITE                             VAX_NAME
# 0                  UNK       NaN      NaN                     HPV (GARDASIL 9)
# 1                    1        OT      NaN          COVID19 (COVID19 (JANSSEN))
# 2                    1       NaN      NaN          COVID19 (COVID19 (JANSSEN))
# 3                    2       NaN       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 4                    1       NaN       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# ...                ...       ...      ...                                  ...
# 276440             UNK        OT      NaN          COVID19 (COVID19 (MODERNA))
# 276441             UNK        OT      NaN          COVID19 (COVID19 (MODERNA))
# 276442             UNK        OT      NaN          COVID19 (COVID19 (MODERNA))
# 276443             UNK        OT      NaN          COVID19 (COVID19 (MODERNA))
# 276444             UNK        OT      NaN           POLIO VIRUS, INACT. (IPOL)
#
# [276445 rows x 42 columns]

# %%
VAERSM = v1.merge(vsymp, on ="VAERS_ID", how='outer')
VAERSM
# Out:
#         VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0        1996873  01/01/2022    CA      NaN      NaN      NaN   U      NaN
# 1        1996874  01/01/2022   NaN      NaN      NaN      NaN   U      NaN
# 2        1996875  01/01/2022    OH      NaN      NaN      NaN   M      NaN
# 3        1996876  01/01/2022    MS     34.0      NaN      NaN   F      NaN
# 4        1996877  01/01/2022    CT      NaN      NaN      NaN   F      NaN
# ...          ...         ...   ...      ...      ...      ...  ..      ...
# 375745   2541569  12/23/2022   NaN      2.0      2.0      0.3   F      NaN
# 375746   2541570  12/23/2022   NaN     68.0      NaN      NaN   F      NaN
# 375747   2541571  12/23/2022   NaN     79.0      NaN      NaN   M      NaN
# 375748   2541572  12/23/2022   NaN     63.0      NaN      NaN   M      NaN
# 375749   2541574  12/23/2022    IN     12.0      NaN      NaN   F      NaN
#
#                                              SYMPTOM_TEXT DIED DATEDIED  \
# 0       This spontaneous report was received from a ph...  NaN      NaN
# 1       SUSPECTED CLINICAL VACCINATION FAILURE; SUSPEC...  NaN      NaN
# 2       SUSPECTED CLINICAL VACCINATION FAILURE; SUSPEC...  NaN      NaN
# 3       Irregular menstrual cycle.; period extremely h...  NaN      NaN
# 4       Breakthrough and heavy periods; longer period ...  NaN      NaN
# ...                                                   ...  ...      ...
# 375745  No adverse event; Vaccine administered after b...  NaN      NaN
# 375746  No adverse event; lot that had been expired wa...  NaN      NaN
# 375747  No adverse event; Expired vaccine used; This s...  NaN      NaN
# 375748  no adverse event; expired vaccine used; This s...  NaN      NaN
# 375749  patient's were administered the IPOL (opened) ...  NaN      NaN
#
#        L_THREAT ER_VISIT HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD    VAX_DATE  \
# 0           NaN      NaN      NaN       NaN    NaN     NaN      U  12/15/2021
# 1           NaN      NaN      NaN       NaN    NaN     NaN      U         NaN
# 2           NaN      NaN      NaN       NaN    NaN     NaN      U         NaN
# 3           NaN      NaN      NaN       NaN    NaN     NaN      N  08/18/2021
# 4           NaN      NaN      NaN       NaN    NaN     NaN      N  03/26/2021
# ...         ...      ...      ...       ...    ...     ...    ...         ...
# 375745      NaN      NaN      NaN       NaN    NaN     NaN      U  07/09/2022
# 375746      NaN      NaN      NaN       NaN    NaN     NaN      U         NaN
# 375747      NaN      NaN      NaN       NaN    NaN     NaN      U         NaN
# 375748      NaN      NaN      NaN       NaN    NaN     NaN      U         NaN
# 375749      NaN      NaN      NaN       NaN    NaN     NaN      U         NaN
#
#         ONSET_DATE  NUMDAYS  \
# 0       12/15/2021      0.0
# 1              NaN      NaN
# 2       12/28/2021      NaN
# 3       09/03/2021     16.0
# 4       06/07/2021     73.0
# ...            ...      ...
# 375745  07/09/2022      0.0
# 375746         NaN      NaN
# 375747         NaN      NaN
# 375748         NaN      NaN
# 375749         NaN      NaN
#
#                                                  LAB_DATA V_ADMINBY V_FUNDBY  \
# 0                                                     NaN       UNK      NaN
# 1                                                     NaN       UNK      NaN
# 2       Test Date: 20211230; Test Name: COVID-19 antig...       OTH      NaN
# 3                                                     NaN       PVT      NaN
# 4       Test Date: 20210921; Test Name: Nasal Swab; Re...       PVT      NaN
# ...                                                   ...       ...      ...
# 375745                                                NaN       UNK      NaN
# 375746                                                NaN       UNK      NaN
# 375747                                                NaN       UNK      NaN
# 375748                                                NaN       UNK      NaN
# 375749                                                NaN       UNK      NaN
#
#                          OTHER_MEDS CUR_ILL  \
# 0                               NaN     NaN
# 1                               NaN     NaN
# 2                               NaN     NaN
# 3       ZOLOFT; ORTHO-TRI-CYCLEN LO     NaN
# 4        ALDACTONE [SPIRONOLACTONE]     NaN
# ...                             ...     ...
# 375745                          NaN     NaN
# 375746                          NaN     NaN
# 375747                          NaN     NaN
# 375748                          NaN     NaN
# 375749                          NaN     NaN
#
#                                                   HISTORY PRIOR_VAX  \
# 0                                                     NaN       NaN
# 1                                                     NaN       NaN
# 2                                                     NaN       NaN
# 3       Comments: List of non-encoded Patient Relevant...       NaN
# 4                                                     NaN       NaN
# ...                                                   ...       ...
# 375745                                                NaN       NaN
# 375746                                                NaN       NaN
# 375747                                                NaN       NaN
# 375748                                                NaN       NaN
# 375749                                                NaN       NaN
#
#                          SPLTTYPE  FORM_VERS TODAYS_DATE BIRTH_DEFECT  \
# 0        US0095075132112USA007320          2  12/31/2021          NaN
# 1             USJNJFOC20211263430          2  01/01/2022          NaN
# 2             USJNJFOC20211266010          2  01/01/2022          NaN
# 3        USPFIZER INC202101162241          2  12/31/2021          NaN
# 4        USPFIZER INC202101281356          2  12/31/2021          NaN
# ...                           ...        ...         ...          ...
# 375745  USMODERNATX, INC.MOD20226          2  12/23/2022          NaN
# 375746  USMODERNATX, INC.MOD20226          2  12/23/2022          NaN
# 375747  USMODERNATX, INC.MOD20226          2  12/23/2022          NaN
# 375748  USMODERNATX, INC.MOD20226          2  12/23/2022          NaN
# 375749           USSA2022SA514948          2  12/23/2022          NaN
#
#        OFC_VISIT ER_ED_VISIT ALLERGIES VAX_TYPE          VAX_MANU  VAX_LOT  \
# 0            NaN         NaN       NaN     HPV9  MERCK & CO. INC.  R017624
# 1            NaN         NaN       NaN  COVID19           JANSSEN      NaN
# 2            NaN         NaN       NaN  COVID19           JANSSEN  204A21A
# 3            NaN         NaN       NaN  COVID19   PFIZER\BIONTECH   Fd8448
# 4            NaN         NaN       NaN  COVID19   PFIZER\BIONTECH   EP6955
# ...          ...         ...       ...      ...               ...      ...
# 375745       NaN         NaN       NaN  COVID19           MODERNA  AS1414B
# 375746       NaN         NaN       NaN  COVID19           MODERNA  O70H21A
# 375747       NaN         NaN       NaN  COVID19           MODERNA  O70H21A
# 375748       NaN         NaN       NaN  COVID19           MODERNA  O70H21A
# 375749       NaN         NaN       NaN      IPV    SANOFI PASTEUR      NaN
#
#        VAX_DOSE_SERIES VAX_ROUTE VAX_SITE  \
# 0                  UNK       NaN      NaN
# 1                    1        OT      NaN
# 2                    1       NaN      NaN
# 3                    2       NaN       LA
# 4                    1       NaN       LA
# ...                ...       ...      ...
# 375745             UNK        OT      NaN
# 375746             UNK        OT      NaN
# 375747             UNK        OT      NaN
# 375748             UNK        OT      NaN
# 375749             UNK        OT      NaN
#
#                                    VAX_NAME                      SYMPTOM1  \
# 0                          HPV (GARDASIL 9)  Expired product administered
# 1               COVID19 (COVID19 (JANSSEN))            Suspected COVID-19
# 2               COVID19 (COVID19 (JANSSEN))               SARS-CoV-2 test
# 3       COVID19 (COVID19 (PFIZER-BIONTECH))                 Dysmenorrhoea
# 4       COVID19 (COVID19 (PFIZER-BIONTECH))      Heavy menstrual bleeding
# ...                                     ...                           ...
# 375745          COVID19 (COVID19 (MODERNA))  Expired product administered
# 375746          COVID19 (COVID19 (MODERNA))  Expired product administered
# 375747          COVID19 (COVID19 (MODERNA))  Expired product administered
# 375748          COVID19 (COVID19 (MODERNA))  Expired product administered
# 375749           POLIO VIRUS, INACT. (IPOL)              Medication error
#
#         SYMPTOMVERSION1                           SYMPTOM2  SYMPTOMVERSION2  \
# 0                  24.1                   No adverse event             24.1
# 1                  24.1                Vaccination failure             24.1
# 2                  24.1                 Suspected COVID-19             24.1
# 3                  24.1           Heavy menstrual bleeding             24.1
# 4                  24.1                    Oligomenorrhoea             24.1
# ...                 ...                                ...              ...
# 375745             25.1                   No adverse event             25.1
# 375746             25.1                   No adverse event             25.1
# 375747             25.1                   No adverse event             25.1
# 375748             25.1                   No adverse event             25.1
# 375749             25.1  Poor quality product administered             25.1
#
#                         SYMPTOM3  SYMPTOMVERSION3 SYMPTOM4  SYMPTOMVERSION4  \
# 0                            NaN              NaN      NaN              NaN
# 1                            NaN              NaN      NaN              NaN
# 2            Vaccination failure             24.1      NaN              NaN
# 3         Menstruation irregular             24.1      NaN              NaN
# 4       SARS-CoV-2 test negative             24.1      NaN              NaN
# ...                          ...              ...      ...              ...
# 375745                       NaN              NaN      NaN              NaN
# 375746                       NaN              NaN      NaN              NaN
# 375747                       NaN              NaN      NaN              NaN
# 375748                       NaN              NaN      NaN              NaN
# 375749                       NaN              NaN      NaN              NaN
#
#        SYMPTOM5  SYMPTOMVERSION5
# 0           NaN              NaN
# 1           NaN              NaN
# 2           NaN              NaN
# 3           NaN              NaN
# 4           NaN              NaN
# ...         ...              ...
# 375745      NaN              NaN
# 375746      NaN              NaN
# 375747      NaN              NaN
# 375748      NaN              NaN
# 375749      NaN              NaN
#
# [375750 rows x 52 columns]

# %% [markdown]
# Checks for duplicated data after merge

# %%
test = VAERSM.duplicated(subset=["VAERS_ID"])
test.value_counts()
# Out:
# False    240841
# True     134909
# dtype: int64

# %% [markdown]
# Checks all cloumns in dataframe

# %%
VAERSM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 375750 entries, 0 to 375749
# Data columns (total 52 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   VAERS_ID         375750 non-null  int64
#  1   RECVDATE         375750 non-null  object
#  2   STATE            311582 non-null  object
#  3   AGE_YRS          332973 non-null  float64
#  4   CAGE_YR          296842 non-null  float64
#  5   CAGE_MO          7581 non-null    float64
#  6   SEX              375750 non-null  object
#  7   RPT_DATE         184 non-null     object
#  8   SYMPTOM_TEXT     375288 non-null  object
#  9   DIED             16665 non-null   object
#  10  DATEDIED         15475 non-null   object
#  11  L_THREAT         9316 non-null    object
#  12  ER_VISIT         36 non-null      object
#  13  HOSPITAL         79730 non-null   object
#  14  HOSPDAYS         55068 non-null   float64
#  15  X_STAY           236 non-null     object
#  16  DISABLE          14984 non-null   object
#  17  RECOVD           315785 non-null  object
#  18  VAX_DATE         342576 non-null  object
#  19  ONSET_DATE       328599 non-null  object
#  20  NUMDAYS          313827 non-null  float64
#  21  LAB_DATA         176843 non-null  object
#  22  V_ADMINBY        375750 non-null  object
#  23  V_FUNDBY         196 non-null     object
#  24  OTHER_MEDS       185865 non-null  object
#  25  CUR_ILL          144392 non-null  object
#  26  HISTORY          205938 non-null  object
#  27  PRIOR_VAX        19915 non-null   object
#  28  SPLTTYPE         136125 non-null  object
#  29  FORM_VERS        375750 non-null  int64
#  30  TODAYS_DATE      367450 non-null  object
#  31  BIRTH_DEFECT     313 non-null     object
#  32  OFC_VISIT        95618 non-null   object
#  33  ER_ED_VISIT      63152 non-null   object
#  34  ALLERGIES        167086 non-null  object
#  35  VAX_TYPE         375750 non-null  object
#  36  VAX_MANU         375750 non-null  object
#  37  VAX_LOT          282042 non-null  object
#  38  VAX_DOSE_SERIES  372182 non-null  object
#  39  VAX_ROUTE        269749 non-null  object
#  40  VAX_SITE         236774 non-null  object
#  41  VAX_NAME         375750 non-null  object
#  42  SYMPTOM1         375750 non-null  object
#  43  SYMPTOMVERSION1  375750 non-null  float64
#  44  SYMPTOM2         281509 non-null  object
#  45  SYMPTOMVERSION2  281509 non-null  float64
#  46  SYMPTOM3         204103 non-null  object
#  47  SYMPTOMVERSION3  204103 non-null  float64
#  48  SYMPTOM4         152613 non-null  object
#  49  SYMPTOMVERSION4  152613 non-null  float64
#  50  SYMPTOM5         121957 non-null  object
#  51  SYMPTOMVERSION5  121957 non-null  float64
# dtypes: float64(10), int64(2), object(40)
# memory usage: 151.9+ MB

# %% [markdown]
# # Searching for symptom

# %% [markdown]
# Searching for myocarditis symptom

# %% [markdown]
# The re.IGNORECASE allows the regular expression to become case-insensitive

# %% [markdown]
# A Regular Expression (RegEx) is a sequence of characters that defines a search pattern.

# %% [markdown]
# na: fill value for missing values. The default depends on dtype of the array.

# %%
found = VAERSM[VAERSM['SYMPTOM_TEXT'].str.contains('myocarditis',na=False, flags=re.IGNORECASE, regex=True)]
found
# Out:
#         VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 346      1997198  01/01/2022    MD     56.0     56.0      NaN   M      NaN
# 347      1997198  01/01/2022    MD     56.0     56.0      NaN   M      NaN
# 384      1997216  01/01/2022    OH     43.0     43.0      NaN   M      NaN
# 458      1997256  01/01/2022    MT     15.0     15.0      NaN   M      NaN
# 479      1997273  01/01/2022    CA     18.0     18.0      NaN   M      NaN
# ...          ...         ...   ...      ...      ...      ...  ..      ...
# 375371   2540525  12/22/2022    VA     64.0     64.0      NaN   M      NaN
# 375372   2540525  12/22/2022    VA     64.0     64.0      NaN   M      NaN
# 375454   2540650  12/22/2022    MI     54.0     54.0      NaN   F      NaN
# 375562   2541334  12/23/2022   NaN      NaN      NaN      NaN   M      NaN
# 375709   2541494  12/23/2022   NaN      NaN      NaN      NaN   U      NaN
#
#                                              SYMPTOM_TEXT DIED DATEDIED  \
# 346     Onset of headache and neck pain 10/10 over 1 m...  NaN      NaN
# 347     Onset of headache and neck pain 10/10 over 1 m...  NaN      NaN
# 384     Thirteen days after I received this dose of th...  NaN      NaN
# 458     chest pain on 12/20/21 intermittently, then co...  NaN      NaN
# 479     The patient developed low grade fevers 24 hour...  NaN      NaN
# ...                                                   ...  ...      ...
# 375371  sudden cardiac arrest, ems response, transport...  NaN      NaN
# 375372  sudden cardiac arrest, ems response, transport...  NaN      NaN
# 375454  Date of Admission: 10/19/2022 Date of Discharg...  NaN      NaN
# 375562  HEART FAILURE; This spontaneous report receive...    Y      NaN
# 375709  there have only been 3 of us (Further clarific...  NaN      NaN
#
#        L_THREAT ER_VISIT HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD    VAX_DATE  \
# 346         NaN      NaN      NaN       NaN    NaN     NaN      U  10/26/2021
# 347         NaN      NaN      NaN       NaN    NaN     NaN      U  10/26/2021
# 384         NaN      NaN      NaN       NaN    NaN     NaN      U  05/29/2021
# 458         NaN      NaN        Y       1.0    NaN     NaN      Y  12/27/2021
# 479           Y      NaN        Y       5.0    NaN     NaN      N  12/21/2021
# ...         ...      ...      ...       ...    ...     ...    ...         ...
# 375371      NaN      NaN        Y       7.0    NaN     NaN      Y  10/14/2022
# 375372      NaN      NaN        Y       7.0    NaN     NaN      Y  10/14/2022
# 375454      NaN      NaN        Y       NaN    NaN     NaN      Y  05/25/2021
# 375562      NaN      NaN      NaN       NaN    NaN     NaN      N         NaN
# 375709      NaN      NaN      NaN       NaN    NaN     NaN      U         NaN
#
#         ONSET_DATE  NUMDAYS  \
# 346     10/26/2021      0.0
# 347     10/26/2021      0.0
# 384     06/11/2021     13.0
# 458     12/30/2021      3.0
# 479     12/23/2021      2.0
# ...            ...      ...
# 375371  11/06/2022     23.0
# 375372  11/06/2022     23.0
# 375454  10/19/2022    512.0
# 375562         NaN      NaN
# 375709         NaN      NaN
#
#                                                  LAB_DATA V_ADMINBY V_FUNDBY  \
# 346                             ECG telemetry showing SVT       OTH      NaN
# 347                             ECG telemetry showing SVT       OTH      NaN
# 384     The following labs were drawn and measured: CB...       PUB      NaN
# 458          elevated troponin, elevated CRP; nml d-dimer       PHM      NaN
# 479     all 2021:  Troponin-I: 12/26 .51 ug/ml, 12/26 ...       PVT      NaN
# ...                                                   ...       ...      ...
# 375371                                                NaN       UNK      NaN
# 375372                                                NaN       UNK      NaN
# 375454          10/19 Covid-19, Flu, RSV by NAA, Detected       UNK      NaN
# 375562                                                NaN       UNK      NaN
# 375709                                                NaN       UNK      NaN
#
#                                                OTHER_MEDS  \
# 346                   famotidine but have not been taking
# 347                   famotidine but have not been taking
# 384     Flecainide, metoprolol, cabergoline, cetirizne...
# 458                                                  none
# 479     Flovent 44 mcg, 2 puffs twice daily, vitamin C...
# ...                                                   ...
# 375371                                               None
# 375372                                               None
# 375454                                                NaN
# 375562                                                NaN
# 375709                                                NaN
#
#                                                   CUR_ILL  \
# 346                                                  None
# 347                                                  None
# 384                                                  None
# 458                                                  none
# 479     subjective sensation of dyspnea since COVID 10...
# ...                                                   ...
# 375371                                               none
# 375372                                               none
# 375454                                                NaN
# 375562                                                NaN
# 375709                                                NaN
#
#                                     HISTORY  \
# 346                                    None
# 347                                    None
# 384     Idiopathic ventricular fibrillation
# 458                                    none
# 479               History of COVID 10/15/21
# ...                                     ...
# 375371                                 none
# 375372                                 none
# 375454                                  NaN
# 375562                                  NaN
# 375709                                  NaN
#
#                                                 PRIOR_VAX  \
# 346     flu vaccine 15 years ago but only neuropathy a...
# 347     flu vaccine 15 years ago but only neuropathy a...
# 384                                                   NaN
# 458                                                   NaN
# 479                                                   NaN
# ...                                                   ...
# 375371                                                NaN
# 375372                                                NaN
# 375454                                                NaN
# 375562                                                NaN
# 375709                                                NaN
#
#                         SPLTTYPE  FORM_VERS TODAYS_DATE BIRTH_DEFECT  \
# 346                          NaN          2  01/01/2022          NaN
# 347                          NaN          2  01/01/2022          NaN
# 384                          NaN          2  01/01/2022          NaN
# 458                          NaN          2  01/01/2022          NaN
# 479                          NaN          2  12/30/2021          NaN
# ...                          ...        ...         ...          ...
# 375371                       NaN          2  12/22/2022          NaN
# 375372                       NaN          2  12/22/2022          NaN
# 375454                       NaN          2         NaN          NaN
# 375562       USJNJFOC20221245816          2  12/22/2022          NaN
# 375709  USPFIZER INC202201387552          2  12/22/2022          NaN
#
#        OFC_VISIT ER_ED_VISIT   ALLERGIES   VAX_TYPE         VAX_MANU  VAX_LOT  \
# 346            Y         NaN  Penicillin    COVID19          JANSSEN      NaN
# 347            Y         NaN  Penicillin    COVID19          JANSSEN      NaN
# 384            Y         NaN        None    COVID19          JANSSEN  1808982
# 458          NaN         NaN        none    COVID19  PFIZER\BIONTECH   ED0809
# 479          NaN           Y        none    COVID19  PFIZER\BIONTECH   FJ1620
# ...          ...         ...         ...        ...              ...      ...
# 375371         Y         NaN        none  COVID19-2          MODERNA      NaN
# 375372         Y         NaN        none  COVID19-2          MODERNA      NaN
# 375454       NaN         NaN         NaN    COVID19  PFIZER\BIONTECH   EW0191
# 375562       NaN         NaN         NaN    COVID19          JANSSEN      NaN
# 375709       NaN         NaN         NaN    COVID19  PFIZER\BIONTECH      NaN
#
#        VAX_DOSE_SERIES VAX_ROUTE VAX_SITE  \
# 346                UNK       NaN      NaN
# 347                UNK       NaN      NaN
# 384                  1       SYR       AR
# 458                  1        IM       LA
# 479                  3        IM       RA
# ...                ...       ...      ...
# 375371               1        IM       LA
# 375372               1        IM       LA
# 375454               2       NaN      NaN
# 375562               1       NaN      NaN
# 375709             UNK       NaN      NaN
#
#                                     VAX_NAME                      SYMPTOM1  \
# 346              COVID19 (COVID19 (JANSSEN))    Cardiac telemetry abnormal
# 347              COVID19 (COVID19 (JANSSEN))                   Myocarditis
# 384              COVID19 (COVID19 (JANSSEN))               Blood magnesium
# 458      COVID19 (COVID19 (PFIZER-BIONTECH))  C-reactive protein increased
# 479      COVID19 (COVID19 (PFIZER-BIONTECH))               Abnormal faeces
# ...                                      ...                           ...
# 375371  COVID19 (COVID19 (MODERNA BIVALENT))                Cardiac arrest
# 375372  COVID19 (COVID19 (MODERNA BIVALENT))                Intensive care
# 375454   COVID19 (COVID19 (PFIZER-BIONTECH))                      COVID-19
# 375562           COVID19 (COVID19 (JANSSEN))               Cardiac failure
# 375709   COVID19 (COVID19 (PFIZER-BIONTECH))                Gait inability
#
#         SYMPTOMVERSION1                            SYMPTOM2  SYMPTOMVERSION2  \
# 346                24.1                            Dyspnoea             24.1
# 347                24.1                           Neck pain             24.1
# 384                24.1   Blood thyroid stimulating hormone             24.1
# 458                24.1                          Chest pain             24.1
# 479                24.1  Alanine aminotransferase increased             24.1
# ...                 ...                                 ...              ...
# 375371             25.1                 Cardiac dysfunction             25.1
# 375372             25.1                         Myocarditis             25.1
# 375454             25.1       Influenza virus test positive             25.1
# 375562             25.1                                 NaN              NaN
# 375709             25.1                         Myocarditis             25.1
#
#                                          SYMPTOM3  SYMPTOMVERSION3  \
# 346                                       Fatigue             24.1
# 347                                  Palpitations             24.1
# 384                              Full blood count             24.1
# 458                         Fibrin D dimer normal             24.1
# 479          Aspartate aminotransferase increased             24.1
# ...                                           ...              ...
# 375371                Cardiac pacemaker insertion             25.1
# 375372                                        NaN              NaN
# 375454  Respiratory syncytial virus test positive             25.1
# 375562                                        NaN              NaN
# 375709                                        NaN              NaN
#
#                             SYMPTOM4  SYMPTOMVERSION4  \
# 346                         Headache             24.1
# 347     Supraventricular tachycardia             24.1
# 384          Metabolic function test             24.1
# 458                      Myocarditis             24.1
# 479       Blood fibrinogen increased             24.1
# ...                              ...              ...
# 375371       Endotracheal intubation             25.1
# 375372                           NaN              NaN
# 375454      SARS-CoV-2 test positive             25.1
# 375562                           NaN              NaN
# 375709                           NaN              NaN
#
#                                      SYMPTOM5  SYMPTOMVERSION5
# 346                                  Insomnia             24.1
# 347                                       NaN              NaN
# 384                  Ventricular fibrillation             24.1
# 458                        Troponin increased             24.1
# 479     Blood lactate dehydrogenase increased             24.1
# ...                                       ...              ...
# 375371    Implantable defibrillator insertion             25.1
# 375372                                    NaN              NaN
# 375454                                    NaN              NaN
# 375562                                    NaN              NaN
# 375709                                    NaN              NaN
#
# [2519 rows x 52 columns]

# %% [markdown]
# Remove duplicate data. You don't remove duplicates at the beginning because an individual can file multiple results and a particular symptom could be reported on the final file

# %% [markdown]
# Pandas drop_duplicates() method helps in removing duplicates from the Pandas Dataframe In Python.

# %%
refine = found.drop_duplicates(subset=['VAERS_ID'],keep='first')
refine
# Out:
#         VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 346      1997198  01/01/2022    MD     56.0     56.0      NaN   M      NaN
# 384      1997216  01/01/2022    OH     43.0     43.0      NaN   M      NaN
# 458      1997256  01/01/2022    MT     15.0     15.0      NaN   M      NaN
# 479      1997273  01/01/2022    CA     18.0     18.0      NaN   M      NaN
# 643      1997414  01/01/2022    CA     50.0     50.0      NaN   M      NaN
# ...          ...         ...   ...      ...      ...      ...  ..      ...
# 375361   2540253  12/22/2022   NaN      5.0      NaN      NaN   F      NaN
# 375371   2540525  12/22/2022    VA     64.0     64.0      NaN   M      NaN
# 375454   2540650  12/22/2022    MI     54.0     54.0      NaN   F      NaN
# 375562   2541334  12/23/2022   NaN      NaN      NaN      NaN   M      NaN
# 375709   2541494  12/23/2022   NaN      NaN      NaN      NaN   U      NaN
#
#                                              SYMPTOM_TEXT DIED DATEDIED  \
# 346     Onset of headache and neck pain 10/10 over 1 m...  NaN      NaN
# 384     Thirteen days after I received this dose of th...  NaN      NaN
# 458     chest pain on 12/20/21 intermittently, then co...  NaN      NaN
# 479     The patient developed low grade fevers 24 hour...  NaN      NaN
# 643                            Cardiac arrest Myocarditis  NaN      NaN
# ...                                                   ...  ...      ...
# 375361  myocarditis; Initial information received on 1...    Y      NaN
# 375371  sudden cardiac arrest, ems response, transport...  NaN      NaN
# 375454  Date of Admission: 10/19/2022 Date of Discharg...  NaN      NaN
# 375562  HEART FAILURE; This spontaneous report receive...    Y      NaN
# 375709  there have only been 3 of us (Further clarific...  NaN      NaN
#
#        L_THREAT ER_VISIT HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD    VAX_DATE  \
# 346         NaN      NaN      NaN       NaN    NaN     NaN      U  10/26/2021
# 384         NaN      NaN      NaN       NaN    NaN     NaN      U  05/29/2021
# 458         NaN      NaN        Y       1.0    NaN     NaN      Y  12/27/2021
# 479           Y      NaN        Y       5.0    NaN     NaN      N  12/21/2021
# 643           Y      NaN        Y       7.0    NaN     NaN      N  12/23/2021
# ...         ...      ...      ...       ...    ...     ...    ...         ...
# 375361      NaN      NaN      NaN       NaN    NaN     NaN      N         NaN
# 375371      NaN      NaN        Y       7.0    NaN     NaN      Y  10/14/2022
# 375454      NaN      NaN        Y       NaN    NaN     NaN      Y  05/25/2021
# 375562      NaN      NaN      NaN       NaN    NaN     NaN      N         NaN
# 375709      NaN      NaN      NaN       NaN    NaN     NaN      U         NaN
#
#         ONSET_DATE  NUMDAYS  \
# 346     10/26/2021      0.0
# 384     06/11/2021     13.0
# 458     12/30/2021      3.0
# 479     12/23/2021      2.0
# 643     12/24/2021      1.0
# ...            ...      ...
# 375361         NaN      NaN
# 375371  11/06/2022     23.0
# 375454  10/19/2022    512.0
# 375562         NaN      NaN
# 375709         NaN      NaN
#
#                                                  LAB_DATA V_ADMINBY V_FUNDBY  \
# 346                             ECG telemetry showing SVT       OTH      NaN
# 384     The following labs were drawn and measured: CB...       PUB      NaN
# 458          elevated troponin, elevated CRP; nml d-dimer       PHM      NaN
# 479     all 2021:  Troponin-I: 12/26 .51 ug/ml, 12/26 ...       PVT      NaN
# 643                                                   NaN       PVT      NaN
# ...                                                   ...       ...      ...
# 375361                                                NaN       UNK      NaN
# 375371                                                NaN       UNK      NaN
# 375454          10/19 Covid-19, Flu, RSV by NAA, Detected       UNK      NaN
# 375562                                                NaN       UNK      NaN
# 375709                                                NaN       UNK      NaN
#
#                                                OTHER_MEDS  \
# 346                   famotidine but have not been taking
# 384     Flecainide, metoprolol, cabergoline, cetirizne...
# 458                                                  none
# 479     Flovent 44 mcg, 2 puffs twice daily, vitamin C...
# 643                                                  None
# ...                                                   ...
# 375361                                                NaN
# 375371                                               None
# 375454                                                NaN
# 375562                                                NaN
# 375709                                                NaN
#
#                                                   CUR_ILL  \
# 346                                                  None
# 384                                                  None
# 458                                                  none
# 479     subjective sensation of dyspnea since COVID 10...
# 643                    Seasonal asthma Seasonal allergies
# ...                                                   ...
# 375361                                                NaN
# 375371                                               none
# 375454                                                NaN
# 375562                                                NaN
# 375709                                                NaN
#
#                                     HISTORY  \
# 346                                    None
# 384     Idiopathic ventricular fibrillation
# 458                                    none
# 479               History of COVID 10/15/21
# 643       Seasonal allergies Sesonal Asthma
# ...                                     ...
# 375361                                  NaN
# 375371                                 none
# 375454                                  NaN
# 375562                                  NaN
# 375709                                  NaN
#
#                                                 PRIOR_VAX  \
# 346     flu vaccine 15 years ago but only neuropathy a...
# 384                                                   NaN
# 458                                                   NaN
# 479                                                   NaN
# 643                                                   NaN
# ...                                                   ...
# 375361                                                NaN
# 375371                                                NaN
# 375454                                                NaN
# 375562                                                NaN
# 375709                                                NaN
#
#                         SPLTTYPE  FORM_VERS TODAYS_DATE BIRTH_DEFECT  \
# 346                          NaN          2  01/01/2022          NaN
# 384                          NaN          2  01/01/2022          NaN
# 458                          NaN          2  01/01/2022          NaN
# 479                          NaN          2  12/30/2021          NaN
# 643                          NaN          2  01/01/2022          NaN
# ...                          ...        ...         ...          ...
# 375361          USSA2022SA513796          2  12/21/2022          NaN
# 375371                       NaN          2  12/22/2022          NaN
# 375454                       NaN          2         NaN          NaN
# 375562       USJNJFOC20221245816          2  12/22/2022          NaN
# 375709  USPFIZER INC202201387552          2  12/22/2022          NaN
#
#        OFC_VISIT ER_ED_VISIT   ALLERGIES   VAX_TYPE              VAX_MANU  \
# 346            Y         NaN  Penicillin    COVID19               JANSSEN
# 384            Y         NaN        None    COVID19               JANSSEN
# 458          NaN         NaN        none    COVID19       PFIZER\BIONTECH
# 479          NaN           Y        none    COVID19       PFIZER\BIONTECH
# 643          NaN           Y        None    COVID19       PFIZER\BIONTECH
# ...          ...         ...         ...        ...                   ...
# 375361       NaN         NaN         NaN       FLUX  UNKNOWN MANUFACTURER
# 375371         Y         NaN        none  COVID19-2               MODERNA
# 375454       NaN         NaN         NaN    COVID19       PFIZER\BIONTECH
# 375562       NaN         NaN         NaN    COVID19               JANSSEN
# 375709       NaN         NaN         NaN    COVID19       PFIZER\BIONTECH
#
#         VAX_LOT VAX_DOSE_SERIES VAX_ROUTE VAX_SITE  \
# 346         NaN             UNK       NaN      NaN
# 384     1808982               1       SYR       AR
# 458      ED0809               1        IM       LA
# 479      FJ1620               3        IM       RA
# 643      FL3197               3        IM       LA
# ...         ...             ...       ...      ...
# 375361      NaN             UNK        OT      NaN
# 375371      NaN               1        IM       LA
# 375454   EW0191               2       NaN      NaN
# 375562      NaN               1       NaN      NaN
# 375709      NaN             UNK       NaN      NaN
#
#                                     VAX_NAME                      SYMPTOM1  \
# 346              COVID19 (COVID19 (JANSSEN))    Cardiac telemetry abnormal
# 384              COVID19 (COVID19 (JANSSEN))               Blood magnesium
# 458      COVID19 (COVID19 (PFIZER-BIONTECH))  C-reactive protein increased
# 479      COVID19 (COVID19 (PFIZER-BIONTECH))               Abnormal faeces
# 643      COVID19 (COVID19 (PFIZER-BIONTECH))                Cardiac arrest
# ...                                      ...                           ...
# 375361  INFLUENZA (SEASONAL) (NO BRAND NAME)                         Death
# 375371  COVID19 (COVID19 (MODERNA BIVALENT))                Cardiac arrest
# 375454   COVID19 (COVID19 (PFIZER-BIONTECH))                      COVID-19
# 375562           COVID19 (COVID19 (JANSSEN))               Cardiac failure
# 375709   COVID19 (COVID19 (PFIZER-BIONTECH))                Gait inability
#
#         SYMPTOMVERSION1                            SYMPTOM2  SYMPTOMVERSION2  \
# 346                24.1                            Dyspnoea             24.1
# 384                24.1   Blood thyroid stimulating hormone             24.1
# 458                24.1                          Chest pain             24.1
# 479                24.1  Alanine aminotransferase increased             24.1
# 643                24.1                         Myocarditis             24.1
# ...                 ...                                 ...              ...
# 375361             25.1                         Myocarditis             25.1
# 375371             25.1                 Cardiac dysfunction             25.1
# 375454             25.1       Influenza virus test positive             25.1
# 375562             25.1                                 NaN              NaN
# 375709             25.1                         Myocarditis             25.1
#
#                                          SYMPTOM3  SYMPTOMVERSION3  \
# 346                                       Fatigue             24.1
# 384                              Full blood count             24.1
# 458                         Fibrin D dimer normal             24.1
# 479          Aspartate aminotransferase increased             24.1
# 643                                           NaN              NaN
# ...                                           ...              ...
# 375361                                        NaN              NaN
# 375371                Cardiac pacemaker insertion             25.1
# 375454  Respiratory syncytial virus test positive             25.1
# 375562                                        NaN              NaN
# 375709                                        NaN              NaN
#
#                           SYMPTOM4  SYMPTOMVERSION4  \
# 346                       Headache             24.1
# 384        Metabolic function test             24.1
# 458                    Myocarditis             24.1
# 479     Blood fibrinogen increased             24.1
# 643                            NaN              NaN
# ...                            ...              ...
# 375361                         NaN              NaN
# 375371     Endotracheal intubation             25.1
# 375454    SARS-CoV-2 test positive             25.1
# 375562                         NaN              NaN
# 375709                         NaN              NaN
#
#                                      SYMPTOM5  SYMPTOMVERSION5
# 346                                  Insomnia             24.1
# 384                  Ventricular fibrillation             24.1
# 458                        Troponin increased             24.1
# 479     Blood lactate dehydrogenase increased             24.1
# 643                                       NaN              NaN
# ...                                       ...              ...
# 375361                                    NaN              NaN
# 375371    Implantable defibrillator insertion             25.1
# 375454                                    NaN              NaN
# 375562                                    NaN              NaN
# 375709                                    NaN              NaN
#
# [1028 rows x 52 columns]

# %% [markdown]
# # Symptom Display

# %%
pd.set_option('display.max_colwidth', None)

# %%
refine[['VAERS_ID','SYMPTOM_TEXT']]
# Out:
#         VAERS_ID  \
# 346      1997198
# 384      1997216
# 458      1997256
# 479      1997273
# 643      1997414
# ...          ...
# 375361   2540253
# 375371   2540525
# 375454   2540650
# 375562   2541334
# 375709   2541494
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  SYMPTOM_TEXT
# 346                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Onset of headache and neck pain 10/10 over 1 minute which resolved after 2 days  After 4 days developed myocarditis with SVT with several bouts of heart rate to 140's and SVT on ECG telemetry.     Palpitations, insomnia, Dyspnea, shortness of breath,  fatigue, headaches.    Gradually resolving over last few months.
# 384                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Thirteen days after I received this dose of the Janssen  COVID vaccine my Automated Internal Cardiac Defibrillator fired twice as I was experiencing ventricular fibrillation. This was not a new condition to me (hence the AICD) but it was the first time being shocked in over 2.5 years, and I have not been shocked since then. The labs run that day show no electrolyte imbalance nor any other common cause that might explain why I was shocked.  I know the Janssen vaccine may cause myocarditis, a common symptom of which is cardiac arrhythmias. I did ask my electrophysiology cardiologist before my vaccination if it was safe for me to do so, and he agreed the risk was worth it. I did not think at the time I was shocked that it might be vaccine-related. I have since asked my EP cardiologist several times if there was any data gathered that might answer the question of whether or not I had myocarditis on June 11, 2021. No one will answer that question.
# 458                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            chest pain on 12/20/21 intermittently, then continued through the night into the early morning on 12/31/21. Seen in the ED with chest pain and had elevated troponin 10K, peak was 12K and elevated crp. Nml d-dimer. Admission for myocarditis overnight stay
# 479                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          The patient developed low grade fevers 24 hours after his flu vaccine  and pfizer booster. Approx 48 hours after the vaccines, his fevers started spiking to tmax 103.7. He was treated at home until 12/26 with alternating ibuprofen and tylenol until 12/26 when, upon discussion with his primary care doc, me, he went to the ER. In ER noted to be hypotensive, tachycardic, and w fever. Also developed vomiting. Given fluids and ceftriaxone. Noted to have elevated troponin, crp, ldh. Normal chest xray. EKG with mild t wave abnormalities which resolved on second EKG. Normal bedside echo. Stabilized, sent to ICU for monitoring. Labs generally improved. Formal Echo normal. On 12/27 developed GI bleed w melanotic stool. sent for EGD and colonoscopy which showed possible mallory weiss tear/gastritis. Placed on protonix and received blood transfusion for drop of hemoglobin from 13 to 8. Advanced diet slowly.  Meanwhile ebv serology came back igm positive, heterophile neg. CMV igm also positive. NO EBV DNA found.  Patient stablized well with down trending troponins and inflammatory markers Hemoglobin stable able to eat and drink Discharged home on protonix and carafate on 12/30/21 Ultimately diagnosed with EBV and hyperinflammatory state. No Misc given self resolving fever and downtrending inflammation without treatement. No myocarditis given normal echo, ekgs, and normal cardiac MRI. It was felt that the elevated troponins were due to cross reactivity with EBV.
# 643                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Cardiac arrest Myocarditis
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 375361                             myocarditis; Initial information received on 16-Dec-2022 regarding an unsolicited valid serious case received from a consumer/non-hcp received from social media page.  This case involves a 5 years old female patient who experienced myocarditis after receiving vaccine influenza vaccine.  It is unknown if the patient had any medical history, concomitant disease or risk factor. The patient's past medical history, medical treatment(s), vaccination(s) and family history were not provided.   On an unknown date, the patient received an unknown dose (units unspecified) of suspect influenza vaccine produced by unknown manufacturer (formulation; strength; lot number and expiry date not reported) via unknown route in unknown administration site for prophylactic vaccination.  On an unknown date the patient had a serious event of myocarditis (unknown latency) following the administration of influenza vaccine.   It was unknown if there were lab data/results available.  Action taken was not applicable.  It was not reported if the patient received a corrective treatment for the event.  At time of reporting, the outcome was Fatal for the event.  No autopsy was done. The cause of death was reported as Myocarditis.  This event was assessed as medically significant and was leading to death.; Sender's Comments: Sanofi company comment for information received on 21-Dec-2022: This case involves a 5 years old female patient who experienced myocarditis after receiving vaccine influenza vaccine. The causal role of the company suspect vaccine cannot be assessed based on the temporal relevance. The time to onset is not reported with the role of the vaccine. Further information regarding concurrent condition during vaccination, previous vaccination, tolerance, allergic history, laboratory investigations , autopsy results excluding alternative etiologies for the reported event are needed to fully assess this case. Based on the data provided, the role of vaccine cannot be assessed.; Reported Cause(s) of Death: myocarditis
# 375371                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           sudden cardiac arrest, ems response, transported to hospital, intubation and restore heart function, four days in ccu, diagnosis myocarditis from the booster, left ventricle 35 percent function, pacemaker  and defibrillator installed, one week in hospital  discharged with medication and restrictions
# 375454                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Date of Admission: 10/19/2022 Date of Discharge: 10/26/2022   Active Hospital Problems   Diagnosis o Heart failure (CMS/HCC) o Stress-induced cardiomyopathy o COVID-19 o Myocarditis (CMS/HCC) o HLD o Coronary artery disease involving native coronary artery of native heart without angina pectoris o HTN
# 375562  HEART FAILURE; This spontaneous report received from a consumer via a company representative via social media concerned a 18 year old male of an unspecified race and ethnicity. The patient's weight, height, and medical history were not reported. The patient received covid-19 vaccine ad26.cov2.s (suspension for injection, route of admin, and batch number were not reported, expiry: unknown) dose was not reported, 1 total, start therapy date were not reported for covid-19 prophylaxis. The batch number was not reported. Per procedure, no follow-up will be requested for this case. No concomitant medications were reported.  On an unspecified date, the patient died from heart failure. It was unspecified if an autopsy was performed. The reporter stated that  "No, you do not have the data. Because injuries are not being reported into VAERS. I had 1 coworker whose lips and tongue went numb after his vaccine, and he nearly died. 2 others had severe tinnitus. One had hands so painful he sat there rubbing them nearly crying. Another had he and his wife both experiencing numb hands with loss of grip. Another coworker's wife has myocarditis. My supervisor's daughter had her 18 year old best friend die of heart failure after his vaccine. These adverse events are not rare, look in every comment section about Covid vaccines. And do not give me that "anecdotal" stuff. Big pharma can not hide behind that lie forever ". The action taken with covid-19 vaccine ad26.cov2.s was not applicable. This report was serious (Death). This case, from the same reporter is linked to 20221243340, 20221243356, 20221243261, 20221243606, 20221245881 and 20221245969.; Sender's Comments: V0: 20221245816- Heart failure.  The event has an unknown/unclear temporal relationship, is unlabeled, and has unknown scientific plausibility. There is no information on any other factors potentially associated with the event. Therefore, the WHO Causality is considered indeterminate. The company causality is considered unassessable.; Reported Cause(s) of Death: HEART FAILURE
# 375709                                                     there have only been 3 of us (Further clarifications unknown) that this is happened to/already reported this to Safety and then she gave all the information about myocardia and not been able to walk.; there have only been 3 of us (Further clarifications unknown) that this is happened to/already reported this to Safety and then she gave all the information about myocardia and not been able to walk.; This is a spontaneous report received from a contactable reporter(s) (Consumer or other non HCP) from medical information team.  A patient (no qualifiers provided) received BNT162b2 (BNT162B2), as dose number unknown, single (Batch/Lot number: unknown) for covid-19 immunisation. The patient's relevant medical history and concomitant medications were not reported. The following information was reported: MYOCARDITIS (medically significant), GAIT INABILITY (non-serious), outcome "unknown" and all described as "there have only been 3 of us (Further clarifications unknown) that this is happened to/already reported this to Safety and then she gave all the information about myocardia and not been able to walk.". Additional information: Reporter mentioned that she already reported this to Safety and then she gave all the information about myocardia and not been able to walk. She wanted compensation for the medial part that haven't been paid and an appointment. She did give this to an attorney. She did state that there have only been 3 of them (further clarifications unknown) that this happened to and reporter did not understand why they do not want to meet with her or why Pfizer does not meet with her. Reporter stated that she filed the adverse event about a year and a half ago because the day after she got the shot, she went to the hospital.  No follow-up attempts are possible; information about lot/batch number cannot be obtained. No further information is expected.; Sender's Comments: Linked Report(s) : US-PFIZER INC-202201387564 same reporter/ product/ event; different patient;
#
# [1028 rows x 2 columns]

# %% [markdown]
# # Searching for death

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Pandas provide many methods to filter a Data frame and Dataframe.query() is one of them.

# %%
rr = VAERSM.query('DIED=="Y"')
rr
# Out:
#         VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 606      1997395  01/01/2022    MS     59.0     59.0      NaN   M      NaN
# 607      1997395  01/01/2022    MS     59.0     59.0      NaN   M      NaN
# 669      1997432  01/01/2022    PA     29.0     29.0      NaN   M      NaN
# 826      2501714  01/01/2022   NaN     80.0     78.0      NaN   M      NaN
# 901      2504173  01/01/2022   NaN     89.0     87.0      NaN   M      NaN
# ...          ...         ...   ...      ...      ...      ...  ..      ...
# 375550   2541324  12/23/2022   NaN      NaN      NaN      NaN   U      NaN
# 375554   2541326  12/23/2022   NaN      NaN      NaN      NaN   M      NaN
# 375562   2541334  12/23/2022   NaN      NaN      NaN      NaN   M      NaN
# 375647   2541439  12/23/2022    NY     75.0     75.0      NaN   M      NaN
# 375707   2541492  12/23/2022    TX      NaN      NaN      NaN   U      NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  SYMPTOM_TEXT  \
# 606                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Hospitalized for fever, seizure, pneumonia 9/3/21 Death by cardiac arrest from blood clot on September 16, 2021
# 607                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Hospitalized for fever, seizure, pneumonia 9/3/21 Death by cardiac arrest from blood clot on September 16, 2021
# 669                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Soon after getting J&J Booster, Patient started complaining about shortness of breath that would come and go.  On 12/22/2021 he was feeling like "crap" and thought it was COVID and was waiting to get tested.  We found him dead in his apartment, and the autopsy revealed pulmonary thrombo embolism.
# 826                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Narrative:  hospice pt
# 901                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Narrative:  hospice pt
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 375550                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    DIED; This spontaneous report received from a consumer via a company representative through social media concerned multiple patients of an unspecified age, sex, race and ethnicity. The patient's weight, height, and medical history were not reported. The patients received covid-19 vaccine ad26.cov2.s (suspension for injection, route of admin, and batch number were not reported, expiry: unknown) dose not reported,1 total, administered on an unspecified date for covid-19 prophylaxis. The batch number was not reported. Per procedure, no follow-up will be requested for this case. No concomitant medications were reported.  On an unspecified date, the patients died from unknown cause of death after they were fully vaccinated. It was unspecified if an autopsy was performed. The reporter stated that, "They were right the only people that I know who have died are fully vaccinated". The action taken with covid-19 vaccine ad26.cov2.s was not applicable. This report was serious (Death).; Sender's Comments: V0-20221243109-Died. Insufficient information is available to make a causality assessment. Therefore, this event is considered unclassifiable.; Reported Cause(s) of Death: UNKNOWN CAUSE OF DEATH
# 375554                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ENDED UP PASSING AWAY; GOT WORSE AND WORSE; This spontaneous report received from a consumer via a company representative via social media concerned a male of unspecified age, race and ethnicity. The patient's weight, height, and medical history were not reported. The patient received covid-19 vaccine ad26.cov2.s (suspension for injection, route of admin, batch number and expiry were not reported) dose, start therapy date were not reported, 1 total, administered for covid-19 prophylaxis. The batch number was not reported. Per procedure no follow-up will be requested for this case. No concomitant medications were reported.  On an unspecified date, the patient got worse and worse and on an unspecified date patient ended up passing away. It was reported that  "My husband got thanks j j shot too years ago and then he got worse and worse and ended up passing away". On an unspecified date, the patient died from unknown cause of death. It was unknown whether an autopsy was performed. The action taken with covid-19 vaccine ad26.cov2.s was not applicable. The outcome of got worse and worse was not reported and on an unspecified date the patient ended up passing away. This report was serious (Death).; Sender's Comments: V0: 20221243958-Ended up passing away. Insufficient information is available to make a causality assessment. Therefore, this event is considered unclassifiable.; Reported Cause(s) of Death: UNKNOWN CAUSE OF DEATH
# 375562  HEART FAILURE; This spontaneous report received from a consumer via a company representative via social media concerned a 18 year old male of an unspecified race and ethnicity. The patient's weight, height, and medical history were not reported. The patient received covid-19 vaccine ad26.cov2.s (suspension for injection, route of admin, and batch number were not reported, expiry: unknown) dose was not reported, 1 total, start therapy date were not reported for covid-19 prophylaxis. The batch number was not reported. Per procedure, no follow-up will be requested for this case. No concomitant medications were reported.  On an unspecified date, the patient died from heart failure. It was unspecified if an autopsy was performed. The reporter stated that  "No, you do not have the data. Because injuries are not being reported into VAERS. I had 1 coworker whose lips and tongue went numb after his vaccine, and he nearly died. 2 others had severe tinnitus. One had hands so painful he sat there rubbing them nearly crying. Another had he and his wife both experiencing numb hands with loss of grip. Another coworker's wife has myocarditis. My supervisor's daughter had her 18 year old best friend die of heart failure after his vaccine. These adverse events are not rare, look in every comment section about Covid vaccines. And do not give me that "anecdotal" stuff. Big pharma can not hide behind that lie forever ". The action taken with covid-19 vaccine ad26.cov2.s was not applicable. This report was serious (Death). This case, from the same reporter is linked to 20221243340, 20221243356, 20221243261, 20221243606, 20221245881 and 20221245969.; Sender's Comments: V0: 20221245816- Heart failure.  The event has an unknown/unclear temporal relationship, is unlabeled, and has unknown scientific plausibility. There is no information on any other factors potentially associated with the event. Therefore, the WHO Causality is considered indeterminate. The company causality is considered unassessable.; Reported Cause(s) of Death: HEART FAILURE
# 375647                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Cardiac arrest/heart attack
# 375707                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    my 43-year-old friend die; This is a spontaneous report received from a contactable reporter(s) (Consumer or other non HCP) from medical information team, Program ID: (005570).  A 43-year-old patient received BNT162b2 (BNT162B2), as dose number unknown, single (Batch/Lot number: unknown) for covid-19 immunisation. The patient's relevant medical history and concomitant medications were not reported. The following information was reported: DEATH (death), outcome "fatal", described as "my 43-year-old friend die". The date and cause of death for the patient were unknown. It was not reported if an autopsy was performed.  Clinical course details: Reporter had the following reports on the Pfizer BioNTech COVID-19 vaccine: The reporter sated that everyone taking the vaccines has had COVID once and twice and the reporter thinks they do not work. The reporter also stated that her cousin who is a nurse worked in operating room and had to go to the hospital she can't see she can't get in the highway to drive, and this is a side effect of the vaccine. She also reported that she saw her 43-year-old friend die. She also stated she don't have any confidence in the vaccine.  The information on the batch/lot number for BNT162b2 has been requested and will be submitted if and when received.; Reported Cause(s) of Death: my 43-year-old friend die
#
#        DIED    DATEDIED L_THREAT ER_VISIT HOSPITAL  HOSPDAYS X_STAY DISABLE  \
# 606       Y  09/16/2021      NaN      NaN        Y      13.0    NaN     NaN
# 607       Y  09/16/2021      NaN      NaN        Y      13.0    NaN     NaN
# 669       Y  12/23/2021      NaN      NaN      NaN       NaN    NaN     NaN
# 826       Y  04/26/2021      NaN      NaN      NaN       NaN    NaN     NaN
# 901       Y  05/24/2021      NaN      NaN      NaN       NaN    NaN     NaN
# ...     ...         ...      ...      ...      ...       ...    ...     ...
# 375550    Y         NaN      NaN      NaN      NaN       NaN    NaN     NaN
# 375554    Y         NaN      NaN      NaN      NaN       NaN    NaN     NaN
# 375562    Y         NaN      NaN      NaN      NaN       NaN    NaN     NaN
# 375647    Y  02/10/2022      NaN      NaN      NaN       NaN    NaN     NaN
# 375707    Y         NaN      NaN      NaN      NaN       NaN    NaN     NaN
#
#        RECOVD    VAX_DATE  ONSET_DATE  NUMDAYS               LAB_DATA  \
# 606         N  08/20/2021  09/01/2021     12.0                    NaN
# 607         N  08/20/2021  09/01/2021     12.0                    NaN
# 669         N  12/02/2021  12/06/2021      4.0  autopsy on 12/27/2021
# 826         U  02/16/2021  04/24/2021     67.0                    NaN
# 901         U  02/02/2021  05/24/2021    111.0                    NaN
# ...       ...         ...         ...      ...                    ...
# 375550      N         NaN         NaN      NaN                    NaN
# 375554      N         NaN         NaN      NaN                    NaN
# 375562      N         NaN         NaN      NaN                    NaN
# 375647      N  09/11/2021  02/01/2022    143.0                   None
# 375707      N         NaN         NaN      NaN                    NaN
#
#        V_ADMINBY V_FUNDBY  \
# 606          PVT      NaN
# 607          PVT      NaN
# 669          PHM      NaN
# 826          OTH      NaN
# 901          OTH      NaN
# ...          ...      ...
# 375550       UNK      NaN
# 375554       UNK      NaN
# 375562       UNK      NaN
# 375647       PVT      NaN
# 375707       UNK      NaN
#
#                                                                   OTHER_MEDS  \
# 606                                                                  Insulin
# 607                                                                  Insulin
# 669     the only thing he took was acid reducer over the counter medication.
# 826                                                                      NaN
# 901                                                                      NaN
# ...                                                                      ...
# 375550                                                                   NaN
# 375554                                                                   NaN
# 375562                                                                   NaN
# 375647                                                               Unknown
# 375707                                                                   NaN
#
#        CUR_ILL                        HISTORY PRIOR_VAX  \
# 606       None                       Diabetes       NaN
# 607       None                       Diabetes       NaN
# 669       None                           None       NaN
# 826        NaN                            NaN       NaN
# 901        NaN                            NaN       NaN
# ...        ...                            ...       ...
# 375550     NaN                            NaN       NaN
# 375554     NaN                            NaN       NaN
# 375562     NaN                            NaN       NaN
# 375647    NONE  Was cleared of COPD by doctor       NaN
# 375707     NaN                            NaN       NaN
#
#                         SPLTTYPE  FORM_VERS TODAYS_DATE BIRTH_DEFECT  \
# 606                          NaN          2  01/01/2022          NaN
# 607                          NaN          2  01/01/2022          NaN
# 669                          NaN          2  01/01/2022          NaN
# 826                          NaN          2  01/01/2022          NaN
# 901                          NaN          2  01/01/2022          NaN
# ...                          ...        ...         ...          ...
# 375550       USJNJFOC20221243109          2  12/22/2022          NaN
# 375554       USJNJFOC20221243958          2  12/22/2022          NaN
# 375562       USJNJFOC20221245816          2  12/22/2022          NaN
# 375647                       NaN          2  12/23/2022          NaN
# 375707  USPFIZER INC202201387530          2  12/22/2022          NaN
#
#        OFC_VISIT ER_ED_VISIT     ALLERGIES VAX_TYPE         VAX_MANU  VAX_LOT  \
# 606          NaN           Y          None  COVID19          MODERNA  059EZIA
# 607          NaN           Y          None  COVID19          MODERNA  059EZIA
# 669          NaN         NaN  Cats, ashtma  COVID19          JANSSEN  213D21A
# 826            Y           Y           NaN  COVID19  PFIZER\BIONTECH      NaN
# 901            Y           Y           NaN  COVID19  PFIZER\BIONTECH      NaN
# ...          ...         ...           ...      ...              ...      ...
# 375550       NaN         NaN           NaN  COVID19          JANSSEN      NaN
# 375554       NaN         NaN           NaN  COVID19          JANSSEN      NaN
# 375562       NaN         NaN           NaN  COVID19          JANSSEN      NaN
# 375647       NaN         NaN          NONE  COVID19  PFIZER\BIONTECH   FC3183
# 375707       NaN         NaN           NaN  COVID19  PFIZER\BIONTECH      NaN
#
#        VAX_DOSE_SERIES VAX_ROUTE VAX_SITE  \
# 606                  1        IM       UN
# 607                  1        IM       UN
# 669                  1        UN       UN
# 826                UNK       NaN      NaN
# 901                UNK       NaN      NaN
# ...                ...       ...      ...
# 375550               1       NaN      NaN
# 375554               1       NaN      NaN
# 375562               1       NaN      NaN
# 375647               1        IM      NaN
# 375707             UNK       NaN      NaN
#
#                                    VAX_NAME         SYMPTOM1  SYMPTOMVERSION1  \
# 606             COVID19 (COVID19 (MODERNA))   Cardiac arrest             24.1
# 607             COVID19 (COVID19 (MODERNA))       Thrombosis             24.1
# 669             COVID19 (COVID19 (JANSSEN))          Autopsy             24.1
# 826     COVID19 (COVID19 (PFIZER-BIONTECH))            Death             25.1
# 901     COVID19 (COVID19 (PFIZER-BIONTECH))            Death             25.1
# ...                                     ...              ...              ...
# 375550          COVID19 (COVID19 (JANSSEN))            Death             25.1
# 375554          COVID19 (COVID19 (JANSSEN))            Death             25.1
# 375562          COVID19 (COVID19 (JANSSEN))  Cardiac failure             25.1
# 375647  COVID19 (COVID19 (PFIZER-BIONTECH))   Cardiac arrest             25.1
# 375707  COVID19 (COVID19 (PFIZER-BIONTECH))            Death             25.1
#
#                                      SYMPTOM2  SYMPTOMVERSION2   SYMPTOM3  \
# 606                                     Death             24.1  Pneumonia
# 607                                       NaN              NaN        NaN
# 669                                     Death             24.1   Dyspnoea
# 826                                       NaN              NaN        NaN
# 901                                       NaN              NaN        NaN
# ...                                       ...              ...        ...
# 375550                                    NaN              NaN        NaN
# 375554  General physical health deterioration             25.1        NaN
# 375562                                    NaN              NaN        NaN
# 375647                  Myocardial infarction             25.1        NaN
# 375707                                    NaN              NaN        NaN
#
#         SYMPTOMVERSION3          SYMPTOM4  SYMPTOMVERSION4  \
# 606                24.1           Pyrexia             24.1
# 607                 NaN               NaN              NaN
# 669                24.1  Feeling abnormal             24.1
# 826                 NaN               NaN              NaN
# 901                 NaN               NaN              NaN
# ...                 ...               ...              ...
# 375550              NaN               NaN              NaN
# 375554              NaN               NaN              NaN
# 375562              NaN               NaN              NaN
# 375647              NaN               NaN              NaN
# 375707              NaN               NaN              NaN
#
#                   SYMPTOM5  SYMPTOMVERSION5
# 606                Seizure             24.1
# 607                    NaN              NaN
# 669     Pulmonary embolism             24.1
# 826                    NaN              NaN
# 901                    NaN              NaN
# ...                    ...              ...
# 375550                 NaN              NaN
# 375554                 NaN              NaN
# 375562                 NaN              NaN
# 375647                 NaN              NaN
# 375707                 NaN              NaN
#
# [16665 rows x 52 columns]

# %% [markdown]
# Removing duplicate data

# %%
pd.set_option('display.max_colwidth', None)
r = rr.drop_duplicates(subset=['VAERS_ID'],keep='first')
r[['VAERS_ID','SYMPTOM_TEXT']]
# Out:
#         VAERS_ID  \
# 606      1997395
# 669      1997432
# 826      2501714
# 901      2504173
# 977      2504256
# ...          ...
# 375550   2541324
# 375554   2541326
# 375562   2541334
# 375647   2541439
# 375707   2541492
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  SYMPTOM_TEXT
# 606                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Hospitalized for fever, seizure, pneumonia 9/3/21 Death by cardiac arrest from blood clot on September 16, 2021
# 669                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Soon after getting J&J Booster, Patient started complaining about shortness of breath that would come and go.  On 12/22/2021 he was feeling like "crap" and thought it was COVID and was waiting to get tested.  We found him dead in his apartment, and the autopsy revealed pulmonary thrombo embolism.
# 826                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Narrative:  hospice pt
# 901                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Narrative:  hospice pt
# 977                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Narrative:  Hospice pt
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 375550                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    DIED; This spontaneous report received from a consumer via a company representative through social media concerned multiple patients of an unspecified age, sex, race and ethnicity. The patient's weight, height, and medical history were not reported. The patients received covid-19 vaccine ad26.cov2.s (suspension for injection, route of admin, and batch number were not reported, expiry: unknown) dose not reported,1 total, administered on an unspecified date for covid-19 prophylaxis. The batch number was not reported. Per procedure, no follow-up will be requested for this case. No concomitant medications were reported.  On an unspecified date, the patients died from unknown cause of death after they were fully vaccinated. It was unspecified if an autopsy was performed. The reporter stated that, "They were right the only people that I know who have died are fully vaccinated". The action taken with covid-19 vaccine ad26.cov2.s was not applicable. This report was serious (Death).; Sender's Comments: V0-20221243109-Died. Insufficient information is available to make a causality assessment. Therefore, this event is considered unclassifiable.; Reported Cause(s) of Death: UNKNOWN CAUSE OF DEATH
# 375554                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ENDED UP PASSING AWAY; GOT WORSE AND WORSE; This spontaneous report received from a consumer via a company representative via social media concerned a male of unspecified age, race and ethnicity. The patient's weight, height, and medical history were not reported. The patient received covid-19 vaccine ad26.cov2.s (suspension for injection, route of admin, batch number and expiry were not reported) dose, start therapy date were not reported, 1 total, administered for covid-19 prophylaxis. The batch number was not reported. Per procedure no follow-up will be requested for this case. No concomitant medications were reported.  On an unspecified date, the patient got worse and worse and on an unspecified date patient ended up passing away. It was reported that  "My husband got thanks j j shot too years ago and then he got worse and worse and ended up passing away". On an unspecified date, the patient died from unknown cause of death. It was unknown whether an autopsy was performed. The action taken with covid-19 vaccine ad26.cov2.s was not applicable. The outcome of got worse and worse was not reported and on an unspecified date the patient ended up passing away. This report was serious (Death).; Sender's Comments: V0: 20221243958-Ended up passing away. Insufficient information is available to make a causality assessment. Therefore, this event is considered unclassifiable.; Reported Cause(s) of Death: UNKNOWN CAUSE OF DEATH
# 375562  HEART FAILURE; This spontaneous report received from a consumer via a company representative via social media concerned a 18 year old male of an unspecified race and ethnicity. The patient's weight, height, and medical history were not reported. The patient received covid-19 vaccine ad26.cov2.s (suspension for injection, route of admin, and batch number were not reported, expiry: unknown) dose was not reported, 1 total, start therapy date were not reported for covid-19 prophylaxis. The batch number was not reported. Per procedure, no follow-up will be requested for this case. No concomitant medications were reported.  On an unspecified date, the patient died from heart failure. It was unspecified if an autopsy was performed. The reporter stated that  "No, you do not have the data. Because injuries are not being reported into VAERS. I had 1 coworker whose lips and tongue went numb after his vaccine, and he nearly died. 2 others had severe tinnitus. One had hands so painful he sat there rubbing them nearly crying. Another had he and his wife both experiencing numb hands with loss of grip. Another coworker's wife has myocarditis. My supervisor's daughter had her 18 year old best friend die of heart failure after his vaccine. These adverse events are not rare, look in every comment section about Covid vaccines. And do not give me that "anecdotal" stuff. Big pharma can not hide behind that lie forever ". The action taken with covid-19 vaccine ad26.cov2.s was not applicable. This report was serious (Death). This case, from the same reporter is linked to 20221243340, 20221243356, 20221243261, 20221243606, 20221245881 and 20221245969.; Sender's Comments: V0: 20221245816- Heart failure.  The event has an unknown/unclear temporal relationship, is unlabeled, and has unknown scientific plausibility. There is no information on any other factors potentially associated with the event. Therefore, the WHO Causality is considered indeterminate. The company causality is considered unassessable.; Reported Cause(s) of Death: HEART FAILURE
# 375647                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Cardiac arrest/heart attack
# 375707                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    my 43-year-old friend die; This is a spontaneous report received from a contactable reporter(s) (Consumer or other non HCP) from medical information team, Program ID: (005570).  A 43-year-old patient received BNT162b2 (BNT162B2), as dose number unknown, single (Batch/Lot number: unknown) for covid-19 immunisation. The patient's relevant medical history and concomitant medications were not reported. The following information was reported: DEATH (death), outcome "fatal", described as "my 43-year-old friend die". The date and cause of death for the patient were unknown. It was not reported if an autopsy was performed.  Clinical course details: Reporter had the following reports on the Pfizer BioNTech COVID-19 vaccine: The reporter sated that everyone taking the vaccines has had COVID once and twice and the reporter thinks they do not work. The reporter also stated that her cousin who is a nurse worked in operating room and had to go to the hospital she can't see she can't get in the highway to drive, and this is a side effect of the vaccine. She also reported that she saw her 43-year-old friend die. She also stated she don't have any confidence in the vaccine.  The information on the batch/lot number for BNT162b2 has been requested and will be submitted if and when received.; Reported Cause(s) of Death: my 43-year-old friend die
#
# [6378 rows x 2 columns]

# %% [markdown]
# # Number of unique VAERS ID

# %%
VID = VAERSM.drop_duplicates(subset=['VAERS_ID'],keep='first')
print(len(VID))
# Out:
# 240841

# %% [markdown]
# # Number of individuals with "stroke" listed as a symptom after receiving a vaccine

# %%
stst = VID[VID['SYMPTOM_TEXT'].str.contains('stroke',na=False, flags=re.IGNORECASE, regex=True)]
print(len(stst))
# Out:
# 2099

# %% [markdown]
# # Number of individuals with "lymph node" listed as a symptom after receiving a vaccine

# %%
lnln = VID[VID['SYMPTOM_TEXT'].str.contains('lymph node',na=False, flags=re.IGNORECASE, regex=True)]
print(len(lnln))
# Out:
# 3709

# %% [markdown]
# # Number of individuals with "heart attack" listed as a symptom after receiving a vaccine

# %%
htht = VID[VID['SYMPTOM_TEXT'].str.contains('heart attack',na=False, flags=re.IGNORECASE, regex=True)]
print(len(htht))
# Out:
# 981

# %% [markdown]
# # Number of individuals with "myocarditis" listed as a symptom after receiving a vaccine

# %%
mymy = VID[VID['SYMPTOM_TEXT'].str.contains('myocarditis',na=False, flags=re.IGNORECASE, regex=True)]
print(len(mymy))
# Out:
# 1028

# %% [markdown]
# # Number of individuals with "blood clot" listed as a symptom after receiving a vaccine

# %%
bcbc = VID[VID['SYMPTOM_TEXT'].str.contains('blood clot',na=False, flags=re.IGNORECASE, regex=True)]
print(len(bcbc))
# Out:
# 1713

# %% [markdown]
# # Number of individuals who were hospitalised after receiving a vaccine

# %%
hh = VID.query('HOSPITAL=="Y"')
print(len(hh))
# Out:
# 28225

# %% [markdown]
# # Number of individuals who received a Moderna vaccine

# %%
mdmd = VID[VID['VAX_MANU'].str.contains('MODERNA',na=False, flags=re.IGNORECASE, regex=True)]
print(len(mdmd))
# Out:
# 88443

# %% [markdown]
# # Number of Moderna doses were received for the Moderna vaccine

# %%
# Calculate the total number of doses of the MODERNA COVID-19 vaccine that have been administered
mdnd = len(VID[(VID['VAX_TYPE'] == 'COVID19') & (VID['VAX_MANU'] == 'MODERNA')])

# Print the total number of doses of the MODERNA COVID-19 vaccine that have been administered
print(mdnd)
# Out:
# 82529

# %% [markdown]
# # Number of individuals who received the Moderna vaccine and died

# %%
mdde = VID[VID['VAX_MANU'].str.contains('MODERNA',na=False, flags=re.IGNORECASE, regex=True) & (VID['DIED'] == 'Y')]
print(f'Number of individuals who died after receiving the PFIZER/BIONTECH COVID-19 vaccine: {len(mdde)}')
# Out:
# Number of individuals who died after receiving the PFIZER/BIONTECH COVID-19 vaccine: 2758

# %% [markdown]
# # Probability of death after taking a Moderna vaccine

# %%
print(len(mdde)/len(mdmd))
# Out:
# 0.031183926370656808

# %% [markdown]
# # Number of individuals who received a PFIZER\BIONTECH vaccine

# %%
pfbn = VID[VID['VAX_MANU'].str.contains(re.compile('PFIZER\\\\BIONTECH', flags=re.IGNORECASE))]
print(f'Number of individuals who received the Pfizer/Biontech COVID-19 vaccine: {len(pfbn)}')
# Out:
# Number of individuals who received the Pfizer/Biontech COVID-19 vaccine: 108929

# %% [markdown]
# # Number of individuals who received the PFIZER\BIONTECH vaccine and died

# %%
pfbnde = VID[VID['VAX_MANU'].str.contains(re.compile('PFIZER\\\\BIONTECH', flags=re.IGNORECASE)) & (VID['DIED'] == 'Y')]
print(f'Number of individuals who died after receiving the PFIZER/BIONTECH COVID-19 vaccine: {len(pfbnde)}')
# Out:
# Number of individuals who died after receiving the PFIZER/BIONTECH COVID-19 vaccine: 2730

# %% [markdown]
# # Probability of death after taking a Pzifer/Biontech vaccine

# %%
print(len(pfbnde)/len(pfbn))
# Out:
# 0.025062196476604025

# %% [markdown]
# # Number of individuals with "disabled" listed as a symptom after receiving a vaccine

# %%
dd = VID.query('DISABLE=="Y"')
print(len(dd))
# Out:
# 5299

# %% [markdown]
# # Number of individual birth defects after receiving a vaccine

# %%
bde = VID.query('BIRTH_DEFECT=="Y"')
print(len(bde))
# Out:
# 141

# %% [markdown]
# # Number of individuals who received a COVID vaccine

# %%
cv19 = VID[VID['VAX_TYPE'].str.contains('COVID19',na=False, flags=re.IGNORECASE, regex=True)]
print(len(cv19))
# Out:
# 207411

# %% [markdown]
# # Number of individual males

# %%
mm = VID.query('SEX=="M"')
print(len(mm))
# Out:
# 87106

# %% [markdown]
# # Number of indvidual females

# %%
ff = VID.query('SEX=="F"')
print(len(ff))
# Out:
# 134582

# %% [markdown]
# # Number of individual undisclosed genders

# %%
other_genders = VID[~VID['SEX'].isin(['M', 'F'])]
print(f'Number of individuals with a gender that is not "M" or "F": {len(other_genders)}')
# Out:
# Number of individuals with a gender that is not "M" or "F": 19153

# %% [markdown]
# # Number of individuals who died who received a vaccine

# %%
print(len(r))
# Out:
# 6378

# %% [markdown]
# # Mean age of individuals who have died

# %%
mean_age_of_deaths = VID[VID['DIED'] == 'Y']['AGE_YRS'].mean()
print(f'Mean age of deaths: {mean_age_of_deaths}')
# Out:
# Mean age of deaths: 73.68455412907703

# %% [markdown]
# # Median age of individuals who have died

# %%
median_age_of_deaths = VID[VID['DIED'] == 'Y']['AGE_YRS'].median()
print(f'Median age of deaths: {median_age_of_deaths}')
# Out:
# Median age of deaths: 76.0

# %% [markdown]
# # Standard deviation of the age of individuals who have died

# %%
std_age_of_deaths = VID[VID['DIED'] == 'Y']['AGE_YRS'].std()
print(f'Standard deviation of age of deaths: {std_age_of_deaths}')
# Out:
# Standard deviation of age of deaths: 15.306238683167143

# %% [markdown]
# # Calculate the minimum and maximum ages of individuals who have died

# %%
min_age_of_deaths = VID[VID['DIED'] == 'Y']['AGE_YRS'].min()
max_age_of_deaths = VID[VID['DIED'] == 'Y']['AGE_YRS'].max()
print(f'Min age of deaths: {min_age_of_deaths}, Max age of deaths: {max_age_of_deaths}')
# Out:
# Min age of deaths: 0.08, Max age of deaths: 107.0

# %% [markdown]
# # The probability of individuals who were hospitalised after receiving a vaccine

# %%
hv = len(hh)/len(VID)
print(hv)
# Out:
# 0.11719350110653917

# %% [markdown]
# # The probability of individuals who were disabled after receiving a vaccine

# %%
dv = len(dd)/len(VID)
print(dv)
# Out:
# 0.0220020677542445

# %% [markdown]
# # The probability of individuals with "myocarditis" listed as a symptom after receiving vaccine

# %%
mv = len(mymy)/len(VID)
print(mv)
# Out:
# 0.004268376231621692

# %% [markdown]
# # The probability of death given that the individual received a vaccine

# %%
print(len(r)/len(VID))
# Out:
# 0.026482201950664547

# %% [markdown]
# # Number of individuals with "stroke" listed as a symptom after receiving the COVID-19 vaccine

# %%
# Calculate the number of individuals with "stroke" listed as a symptom after receiving the COVID-19 vaccine
cvst = VID[(VID['SYMPTOM_TEXT'].str.contains('stroke',na=False, flags=re.IGNORECASE, regex=True)) & (VID['VAX_TYPE'] == 'COVID19')]
print(f'Number of individuals with "stroke" listed as a symptom after receiving the COVID-19 vaccine: {len(cvst)}')
# Out:
# Number of individuals with "stroke" listed as a symptom after receiving the COVID-19 vaccine: 1912

# %% [markdown]
# # Number of individuals with "lymph node" listed as a symptom after receiving the COVID-19 vaccine

# %%
# Calculate the number of individuals with "lymph node" listed as a symptom after receiving the COVID-19 vaccine
cvln = VID[(VID['SYMPTOM_TEXT'].str.contains('lymph node',na=False, flags=re.IGNORECASE, regex=True)) & (VID['VAX_TYPE'] == 'COVID19')]
print(f'Number of individuals with "lymph node" listed as a symptom after receiving the COVID-19 vaccine: {len(cvln)}')
# Out:
# Number of individuals with "lymph node" listed as a symptom after receiving the COVID-19 vaccine: 3266

# %% [markdown]
# # Number of individuals with "heart attack" listed as a symptom after receiving the COVID-19 vaccine

# %%
# Calculate the number of individuals with "heart attack" listed as a symptom after receiving the COVID-19 vaccine
cvha = VID[(VID['SYMPTOM_TEXT'].str.contains('heart attack',na=False, flags=re.IGNORECASE, regex=True)) & (VID['VAX_TYPE'] == 'COVID19')]
print(f'Number of individuals with "heart attack" listed as a symptom after receiving the COVID-19 vaccine: {len(cvha)}')
# Out:
# Number of individuals with "heart attack" listed as a symptom after receiving the COVID-19 vaccine: 891

# %% [markdown]
# # Number of individuals with "myocarditis" listed as a symptom after receiving the COVID-19 vaccine

# %%
# Calculate the number of individuals with "myocarditis" listed as a symptom after receiving the COVID-19 vaccine
cvma = VID[(VID['SYMPTOM_TEXT'].str.contains('myocarditis',na=False, flags=re.IGNORECASE, regex=True)) & (VID['VAX_TYPE'] == 'COVID19')]
print(f'Number of individuals with "myocarditis" listed as a symptom after receiving the COVID-19 vaccine: {len(cvma)}')
# Out:
# Number of individuals with "myocarditis" listed as a symptom after receiving the COVID-19 vaccine: 967

# %% [markdown]
# # Number of individuals with "blood clot" listed as a symptom after receiving the COVID-19 vaccine

# %%
# Calculate the number of individuals with "blood clot" listed as a symptom after receiving the COVID-19 vaccine
cvbc = VID[(VID['SYMPTOM_TEXT'].str.contains('blood clot',na=False, flags=re.IGNORECASE, regex=True)) & (VID['VAX_TYPE'] == 'COVID19')]
print(f'Number of individuals with "blood clot" listed as a symptom after receiving the COVID-19 vaccine: {len(cvbc)}')
# Out:
# Number of individuals with "blood clot" listed as a symptom after receiving the COVID-19 vaccine: 1631

# %% [markdown]
# # Number of individuals with "stroke" listed as a symptom after receiving the Pfizer/Biontech COVID-19 vaccine

# %%
# Calculate the number of individuals with "stroke" listed as a symptom after receiving the Pfizer/Biontech COVID-19 vaccine
cvstpf = VID[(VID['SYMPTOM_TEXT'].str.contains('stroke',na=False, flags=re.IGNORECASE, regex=True)) & (VID['VAX_TYPE'] == 'COVID19') & (VID['VAX_MANU'].str.contains(re.compile('PFIZER\\\\BIONTECH', flags=re.IGNORECASE)))]
print(f'Number of individuals with "stroke" listed as a symptom after receiving the Pfizer/Biontech COVID-19 vaccine: {len(cvstpf)}')
# Out:
# Number of individuals with "stroke" listed as a symptom after receiving the Pfizer/Biontech COVID-19 vaccine: 923

# %% [markdown]
# # Number of individuals with "stroke" listed as a symptom after receiving the Moderna COVID-19 vaccine

# %%
# Calculate the number of individuals with "stroke" listed as a symptom after receiving the Moderna COVID-19 vaccine
cvstma = VID[(VID['SYMPTOM_TEXT'].str.contains('stroke',na=False, flags=re.IGNORECASE, regex=True)) & (VID['VAX_TYPE'] == 'COVID19') & (VID['VAX_MANU'].str.contains(re.compile('MODERNA', flags=re.IGNORECASE)))]
print(f'Number of individuals with "stroke" listed as a symptom after receiving the Moderna COVID-19 vaccine: {len(cvstma)}')
# Out:
# Number of individuals with "stroke" listed as a symptom after receiving the Moderna COVID-19 vaccine: 769

# %% [markdown]
# # Number of individuals with "lymph nodes" listed as a symptom after receiving the Pfizer/Biontech COVID-19 vaccine

# %%
# Calculate the number of individuals with "lymph nodes" listed as a symptom after receiving the Pfizer/Biontech COVID-19 vaccine
cvlnpf = VID[(VID['SYMPTOM_TEXT'].str.contains('lymph node',na=False, flags=re.IGNORECASE, regex=True)) & (VID['VAX_TYPE'] == 'COVID19') & (VID['VAX_MANU'].str.contains(re.compile('PFIZER\\\\BIONTECH', flags=re.IGNORECASE)))]
print(f'Number of individuals with "lymph node" listed as a symptom after receiving the Pfizer/Biontech COVID-19 vaccine: {len(cvlnpf)}')
# Out:
# Number of individuals with "lymph node" listed as a symptom after receiving the Pfizer/Biontech COVID-19 vaccine: 2095

# %% [markdown]
# # Number of individuals with "lymph node" listed as a symptom after receiving the Moderna COVID-19 vaccine

# %%
# Calculate the number of individuals with "lymph node" listed as a symptom after receiving the Moderna COVID-19 vaccine
cvlnma = VID[(VID['SYMPTOM_TEXT'].str.contains('lymph node',na=False, flags=re.IGNORECASE, regex=True)) & (VID['VAX_TYPE'] == 'COVID19') & (VID['VAX_MANU'].str.contains(re.compile('MODERNA', flags=re.IGNORECASE)))]
print(f'Number of individuals with "lymph node" listed as a symptom after receiving the Moderna COVID-19 vaccine: {len(cvlnma)}')
# Out:
# Number of individuals with "lymph node" listed as a symptom after receiving the Moderna COVID-19 vaccine: 1092

# %% [markdown]
# # Number of individuals with "heart attack" listed as a symptom after receiving the Pfizer/Biontech COVID-19 vaccine

# %%
# Calculate the number of individuals with "heart attack" listed as a symptom after receiving the Pfizer/Biontech COVID-19 vaccine
cvhapf = VID[(VID['SYMPTOM_TEXT'].str.contains('heart attack',na=False, flags=re.IGNORECASE, regex=True)) & (VID['VAX_TYPE'] == 'COVID19') & (VID['VAX_MANU'].str.contains(re.compile('PFIZER\\\\BIONTECH', flags=re.IGNORECASE)))]
print(f'Number of individuals with "heart attack" listed as a symptom after receiving the Pfizer/Biontech COVID-19 vaccine: {len(cvhapf)}')
# Out:
# Number of individuals with "heart attack" listed as a symptom after receiving the Pfizer/Biontech COVID-19 vaccine: 493

# %% [markdown]
# # Number of individuals with "heart attack" listed as a symptom after receiving the Moderna COVID-19 vaccine

# %%
# Calculate the number of individuals with "heart attack" listed as a symptom after receiving the Moderna COVID-19 vaccine
cvhama = VID[(VID['SYMPTOM_TEXT'].str.contains('heart attack',na=False, flags=re.IGNORECASE, regex=True)) & (VID['VAX_TYPE'] == 'COVID19') & (VID['VAX_MANU'].str.contains(re.compile('MODERNA', flags=re.IGNORECASE)))]
print(f'Number of individuals with "heart attack" listed as a symptom after receiving the Moderna COVID-19 vaccine: {len(cvhama)}')
# Out:
# Number of individuals with "heart attack" listed as a symptom after receiving the Moderna COVID-19 vaccine: 307

# %% [markdown]
# # Number of individuals with "myocarditis" listed as a symptom after receiving the Pfizer/Biontech COVID-19 vaccine

# %%
# Calculate the number of individuals with "myocarditis" listed as a symptom after receiving the Pfizer/Biontech COVID-19 vaccine
cvmypf = VID[(VID['SYMPTOM_TEXT'].str.contains('myocarditis',na=False, flags=re.IGNORECASE, regex=True)) & (VID['VAX_TYPE'] == 'COVID19') & (VID['VAX_MANU'].str.contains(re.compile('PFIZER\\\\BIONTECH', flags=re.IGNORECASE)))]
print(f'Number of individuals with "myocarditis" listed as a symptom after receiving the Pfizer/Biontech COVID-19 vaccine: {len(cvmypf)}')
# Out:
# Number of individuals with "myocarditis" listed as a symptom after receiving the Pfizer/Biontech COVID-19 vaccine: 530

# %% [markdown]
# # Number of individuals with "myocarditis" listed as a symptom after receiving the Moderna COVID-19 vaccine

# %%
# Calculate the number of individuals with "myocarditis" listed as a symptom after receiving the Moderna COVID-19 vaccine
cvmyma = VID[(VID['SYMPTOM_TEXT'].str.contains('myocarditis',na=False, flags=re.IGNORECASE, regex=True)) & (VID['VAX_TYPE'] == 'COVID19') & (VID['VAX_MANU'].str.contains(re.compile('MODERNA', flags=re.IGNORECASE)))]
print(f'Number of individuals with "myocarditis" listed as a symptom after receiving the Moderna COVID-19 vaccine: {len(cvmyma)}')
# Out:
# Number of individuals with "myocarditis" listed as a symptom after receiving the Moderna COVID-19 vaccine: 381

# %% [markdown]
# # Number of individuals with "blood clot" listed as a symptom after receiving the Pfizer/Biontech COVID-19 vaccine

# %%
# Calculate the number of individuals with "blood clot" listed as a symptom after receiving the Pfizer/Biontech COVID-19 vaccine
cvbcpf = VID[(VID['SYMPTOM_TEXT'].str.contains('blood clot',na=False, flags=re.IGNORECASE, regex=True)) & (VID['VAX_TYPE'] == 'COVID19') & (VID['VAX_MANU'].str.contains(re.compile('PFIZER\\\\BIONTECH', flags=re.IGNORECASE)))]
print(f'Number of individuals with "blood clot" listed as a symptom after receiving the Pfizer/Biontech COVID-19 vaccine: {len(cvbcpf)}')
# Out:
# Number of individuals with "blood clot" listed as a symptom after receiving the Pfizer/Biontech COVID-19 vaccine: 748

# %% [markdown]
# # Number of individuals with "blood clot" listed as a symptom after receiving the Moderna COVID-19 vaccine

# %%
# Calculate the number of individuals with "blood clot" listed as a symptom after receiving the Moderna COVID-19 vaccine
cvbcma = VID[(VID['SYMPTOM_TEXT'].str.contains('blood clot',na=False, flags=re.IGNORECASE, regex=True)) & (VID['VAX_TYPE'] == 'COVID19') & (VID['VAX_MANU'].str.contains(re.compile('MODERNA', flags=re.IGNORECASE)))]
print(f'Number of individuals with "blood clot" listed as a symptom after receiving the Moderna COVID-19 vaccine: {len(cvbcma)}')
# Out:
# Number of individuals with "blood clot" listed as a symptom after receiving the Moderna COVID-19 vaccine: 541

# %% [markdown]
# # Number of individuals who died after receiving the COVID-19 vaccine

# %%
cvde = VID[(VID['VAX_TYPE'] == 'COVID19') & (VID['DIED'] == 'Y')]
# Print the number of individuals who died after receiving the COVID-19 vaccine
print(f'Number of individuals who died after receiving the COVID-19 vaccine: {len(cvde)}')
# Out:
# Number of individuals who died after receiving the COVID-19 vaccine: 6088

# %% [markdown]
# # The probability of individuals aquiring a "stroke" after receiving a COVID-19 vaccine

# %%
print(len(cvst)/len(cv19))
# Out:
# 0.009218411752510716

# %% [markdown]
# # The probability of individuals aquiring a "lymph node" after receiving a COVID-19 vaccine

# %%
print(len(cvln)/len(cv19))
# Out:
# 0.01574651296218619

# %% [markdown]
# # The probability of individuals aquiring a "heart attack" after receiving a COVID-19 vaccine

# %%
print(len(cvha)/len(cv19))
# Out:
# 0.004295818447430464

# %% [markdown]
# # The probability of individuals aquiring a "myocarditis" after receiving a COVID-19 vaccine

# %%
print(len(cvma)/len(cv19))
# Out:
# 0.004662240671902647

# %% [markdown]
# # The probability of individuals aquiring a "blood clot" after receiving a COVID-19 vaccine

# %%
print(len(cvbc)/len(cv19))
# Out:
# 0.007863613790975407

# %% [markdown]
# # The probability of dying after receiving the COVID-19 vaccine

# %%
print(len(cvde)/len(cv19))
# Out:
# 0.029352348718245415
